# %%
from twitterscraper import main
from twitterscraper import query
from twitterscraper import tweet
import pandas as pd
import numpy as np
from twitterscraper import query_tweets

# %%
from __future__ import division
import random
import requests
import datetime as dt
import json
from functools import partial
from multiprocessing.pool import Pool

from twitterscraper.tweet import Tweet

# %%
from konlpy.tag import *

# %%
twitter = Twitter()
# Out:
# C:\Users\sora\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#  query_tweets(query, limit = None, begindate = dt.date(2006,3,21), enddate=dt.date.today(), poolsize=20, lang='')
if __name__ == '__main__':
    # 2019 03 08-2019 03 09 공기청정기와 미세먼지  언급된 tweet 찾음
    list_of_tweets = query_tweets("공기청정기 미세먼지", begindate = dt.date(2019,3,8) ,  enddate=dt.date(2019,3,9), poolsize =50)

    #하나씩 print
    for tweet in query_tweets("공기청정기 미세먼지", begindate = dt.date(2019,3,8),enddate=dt.date(2019,3,9), poolsize = 50):
        print(tweet)
# Out:
# INFO: queries: ['공기청정기 미세먼지 since:2019-03-08 until:2019-03-09']
# INFO: Got 131 tweets (131 new).
# INFO: queries: ['공기청정기 미세먼지 since:2019-03-08 until:2019-03-09']
# INFO: Got 131 tweets (131 new).
# <twitterscraper.tweet.Tweet object at 0x000001A09D6F32E8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02588>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E025F8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02630>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E026A0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E026D8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02710>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02748>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02780>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E027B8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E027F0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02828>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02860>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02898>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E028D0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02908>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02978>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E029B0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02A20>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02A58>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02AC8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02B00>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02B38>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02B70>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02BE0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02C18>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02C88>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02CF8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02D30>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02D68>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02DA0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02DD8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02E10>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02E80>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02EB8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02EF0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02F60>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02F98>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E02FD0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09048>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09080>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E090B8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E090F0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09128>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09198>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E091D0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09240>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09278>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E092B0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E092E8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09358>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09390>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E093C8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09470>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E094A8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09518>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09550>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09588>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E095F8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09630>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E096A0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E096D8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09710>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09780>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E097B8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E097F0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09828>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09860>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09898>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E098D0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09940>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09978>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E099B0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09A20>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09A90>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09AC8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09B00>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09B38>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09BA8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09BE0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09C18>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09C50>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09C88>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09CF8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09D30>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09D68>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09DA0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09DD8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09E10>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09E80>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09EF0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09F28>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09F60>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E09F98>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18048>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18080>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E180B8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18128>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18160>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E181D0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18240>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18278>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E182B0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18320>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18390>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E183C8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18400>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18470>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E184A8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E184E0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18588>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E185F8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18630>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E186A0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E186D8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18710>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18748>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18780>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E187B8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E187F0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18828>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18860>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18898>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E188D0>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18908>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18978>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E189E8>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18A20>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18A58>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18A90>
# <twitterscraper.tweet.Tweet object at 0x000001A0B1E18AC8>

# %%
text=""

# %%
#200개 정도만 분석
for i in range((len(list_of_tweets))) :
    text+=(list_of_tweets[i].text)

# %%
text
# Out:
# 'ㅇㅋ\nㅋㅋㅋ\nㅋ\nㅋㅋ\nㅋㅋㅋ 아진짜요?? 나 탈한국할래.. 한국인들 외국가면 공부 잘할거같애요 이 인간들 인간이 아님... 아니 전..아니난죽게해줘... 한국 교육열 제발 그만~~ 미세먼지 오지는데... 시교육청이 초등학교만 공기청정기 주고 중고등학교 아직도 공기청정기도 없어요“중국산 미세먼지에 샤오미 공기청정기 안돼” 반중 불매운동 확산\n출처 : 국민일보 | 네이버\n http://naver.me/GbKdPDrL\xa0시리얼먹구 머리말리고 바로가야지 얼굴부워서 얼굴이 무거웤ㅋㅋ\n\n그나마 미세먼지 좀 물러났다고 숨쉬기편하게 잤다.  미쳤어증말 공기청정기사야한다 비염인의 필수생존템;;;(점막손상으로코피로죽는건가출혈\n\n아님 콧구멍 혈관을 어캐(검열)해야하나 넘성가심;택배하는사람입니다 \n\n이번주 배달 물량중 가장많이 \n늘어난 제품이 무엇일까요\n\n제가 느끼기에 가장 늘어난건\n\n마스크와 공기청정기가 많이\n늘었습니다 \n\n그만큼 미세먼지의 심각성을\n느끼는 분들이 많은거겠죠\n\n시간이 좀더지나면 황사까지 올텐데\n외부에서 일하는 분들 건강에\n유의하세요박원숭 미세먼지 페인트 뉴스보니 옥상양봉 생각나네 지긋지긋하다 하긴 공기청정기 설치하란 사람이나..하는 짓을 보면 대가리에 든 게 없는 게 맞는 것 같다.\n이 너른 천지에 공기청정기로 미세먼지를 막아낸다니\n상식적으로 도저히 이해가 되지 않는다.\n차리 그 돈으로 모든 국민들에게 KF마스크를 배부하는 게 훨 낫지 않은가?국민여러분 미세먼지가 많습니다 방독면사십쇼 공기청정기 사십쇼우리 회사더 공기청정기 있지만 건물 밖에 나오면 미세먼지 잔뜩 있잖아ㅋㅋㅋㅋㅋ그래서 요즘에 목도 안 좋고, 눈도 뭔가 따가워ㅋㅋㅋㅋㅋ나 감기 두 달 정도 안 낫고 있어. 그래도 봄이라 좀 나아졌는데, 겨울엔 너무 힘들었다 ㅋㅋㅋㅋㅋ애기는 괜찮아?요즘 미세먼지 엄청나게 많죠... 인천이 가장 많다는데 ㅠㅠ 그래도 학교에는 공기청정기 많이 설치해줘서 다행이지만! 미세먼지 조심하세요 ㅠㅠ#스모그 #공해 #매연 #마스크 #SUV #노후차 #미세먼지 #배출가스 #자연보호 #대기오염 #환경오염 #발암물질 #유해물질 #역학조사 #공기청정기 #집단소송제 #징벌적_손해배상제https://news.v.daum.net/v/20190308213850599\xa0…공기 양극화라는 말이 나오지 않도록 마스크와 공기청정기 소득공제 서둘러야\n\n#스모그 #공해 #매연 #마스크 #SUV #노후차 #미세먼지 #배출가스 #자연보호 #대기오염 #환경오염 #발암물질 #유해물질 #역학조사 #공기청정기 #집단소송제 #징벌적_손해배상제https://news.v.daum.net/v/20190308213650584\xa0…손바닥으로 해를 가리나\n\n#스모그 #공해 #매연 #마스크 #SUV #노후차 #미세먼지 #배출가스 #자연보호 #대기오염 #환경오염 #발암물질 #유해물질 #역학조사 #공기청정기 #집단소송제 #징벌적_손해배상제https://news.v.daum.net/v/20190308211420267\xa0…#스모그 #공해 #매연 #마스크 #SUV #노후차 #미세먼지 #배출가스 #자연보호 #대기오염 #환경오염 #발암물질 #유해물질 #역학조사 #공기청정기 #집단소송제 #징벌적_손해배상제https://news.v.daum.net/v/20190308210619181\xa0…자연발생처럼 느끼도록 만들어진 미세먼지라는 말부터 틀렸다, 이건 스모그\n\n#스모그 #공해 #매연 #마스크 #SUV #노후차 #미세먼지 #배출가스 #자연보호 #대기오염 #환경오염 #발암물질 #유해물질 #역학조사 #공기청정기 #집단소송제 #징벌적_손해배상제https://news.v.daum.net/v/20190308201502399\xa0…미세먼지로 국민들이 드러누울판인데 아직도과거사냐\n무능한 정부때문에 속하는사람많다 그런데 민심과 뉴스보도하는 지지율은 반대로가니 좀이상하다 아무래도ᆢ\nㅡㅡㅡㅡㅡㅡ\n거리에 대형 공기청정기? 쏟아지는 대책 실효성 있나 (출처 : SBS | 네이버 뉴스) http://naver.me/FJ25PuWt\xa0[출연] 쿠쿠·대유위니아 공기청정기 수요로 상반기 \'호실적\' 예고... "미세먼지 특수" https://goo.gl/fb/qPnkxw\xa0이건 진짜 오늘부터 내 힐링영상 리스트에 추가다.. 아까 혐생 중에 보고 나도 모르게 개저웃음 지음... 찍는거 보고 정색하기 전에 완전 무장해제 웃음 짓는 텐 보고 미세먼지에 뒤덮힌 몸과 마음이 싹 정화됐다. 공기청정기가 다 무슨 필요냐 이 영상 하나면 새 사람 된다. pic.twitter.com/XQixm2H28J공기청정기, 제습기, 가습기, 스타일러(미세먼지 제거용), 에어컨, 난방기 정도는 갖춰야 윤택한 삶이 될 수 있다는 거 너무 슬프다그렇게 싫으면 나가 살든가? 등신아 미세먼지가 어제 오늘 일도 아니고 중국에 항의만 하면 미세먼지가 없어지냐?  미세먼지 40퍼센트는 기레기들의 허풍이라는거 몰라? 공기청정기 같은  광고 만들려고 공포심 조장하는 아주 미세먼지보다도 못한 인간 일세. https://twitter.com/Wl8PuUXBFheeO37/status/1103955044905308160\xa0…요즘 공기청정기 제조사•판매업자들 미세먼지가 너무 사랑스럽지 않을까함~공기청정기 .. 마스크 .. 난 필요없다 극한의 미세먼지속에서조차 청량한 동스청 pic.twitter.com/SpKBhmjM0S알죠....미세먼지와 함께 하던 지난 일주일 간의 등교....로 쌓엿던 스트레스....다 날아가버렷네요....슈짐 나의 공기청정기....^^야자할때 ㄹㅇ 응원의 컵.... 미세먼지속에서 청정 공기청정기 역할에 동기부여 짠ㅁ장임...울 태형잉.. 밖에 나가지말고 숨겨야돼 미세먼지 마시면 안돼ㅠㅠ 집에서 공기청정기 틀어놓고 연탄이랑 놀아https://news.v.daum.net/v/20190308213650584?rcmd=rn&f=m\xa0… 미세먼지에 죽을래, 이산화탄소에 죽을래?  미세먼지에 죽을래, 방사능에 죽을래?  어차피 다 죽게 되어있다. 공기청정기 장사들만 노났네. 나중에 가습기처럼 문제되는 일 없게 해라태양광으로 공기청정기인 숲이 사라지는 건 미세먼지(대기오염)와 상관이 없는 일일까?아아 사립고 외쳐 갓 사립고,, 공기청정기,, 쾌적한 실내 환경,, 미세먼지 흡입,,, 시발이게뭔일이냐진짜세상에난리났다난리나민윥기가나라고나라가민윥기다이각박한세상윥기너하나로버틴다내가진짜미세먼지다필요없어너하나면공기청정기오조오억개돌리는느낌이다윥기야진짜주접이아니아사실이야생일축하해말랑뽀짝아태어나줘서고마워 pic.twitter.com/WECKVn0Jmf공기청정기 틀고 창문 꽉…이산화탄소에 ‘숨 막히는 교실’ / KBS뉴스(News) \n\n“최근 뉴스를 보면 공기조화설비를 갖춰도 미세먼지에 대응하는데 한계가 있다고 했지만 환기를 위해 외기를 일부 도입하고 내부 내기를 일부 리턴하여 적절한 수준을 유지하는 것이라 메인으로”\n\nhttps://youtu.be/nrQ5qs0WGTM\xa0ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ애기 언니 맴 조지게 흔드네ㅠ 살앙해 내 수명을 니가 연장시킨다 야......마스크랑 공기청정기 둬야겠다 사실 얼른 미세먼지 흡수하고 수명 깎을 생각이엇어......나? 항뇬.. 그리고 독마님이 있어 미세먼지도 공기청정기가 됩니다..."나? 나는.. 요즘 미세먼지가 너무 심해서 공기청정기가 좋더라 하나 사서 집에 두려고~"정말 민윤기보고 너무 귀여워서 미세먼지도 돌아가겠다 인간공기청정기로 지정해야 돼 pic.twitter.com/VSg6o5NXzO성영고 세계관에도 미세먼지가 있을까 ㄷ공기청정기 능력 소유자가 한명쯤은 있지 않을까? ((공기청정기 필요한가요? 집안의 공기만 정화하는게 의미가 있을까 싶어서요. 사람이 집안에서만 살 수 있는게 아닌데, 밖에 나가면 어찌피 미세먼지 그대로 마시는데. — 필요해요 https://lap78.ask.fm/igoto/45DKECPW7B667HQMHN2IG6NM7OODDKQ3Q7V6LR5RCD43F55J2RWZGY2LFJE42QRXKK6PKEYOAYUWOPQT3UY7C65IGTZ3JLRHXEKAPBDCBV2TQGPRDDNSSJPDQORN ...

# %%
# 특정 요소만 제외하고 싶을 때, 
# 한글 처리시 유용
def make_corpus_rm_stopwords(text):
    corpus = []
    for s in text.split('\n'):
        # 지정된 요소 아닌 것들만.
        corpus.append(['/'.join(p) for p in twitter.pos(s) if (p[1] not in["Josa","Punctuation","URL"])])
    return corpus

# %%
corpus = make_corpus_rm_stopwords(text)
corpus
# Out:
# [['ㅇㅋ/KoreanParticle'],
#  ['ㅋㅋㅋ/KoreanParticle'],
#  ['ㅋ/KoreanParticle'],
#  ['ㅋㅋ/KoreanParticle'],
#  ['ㅋㅋㅋ/KoreanParticle',
#   '아/Exclamation',
#   '진짜/Noun',
#   '나/Noun',
#   '탈/Noun',
#   '한국/Noun',
#   '할래/Verb',
#   '한국/Noun',
#   '외국/Noun',
#   '가면/Noun',
#   '공부/Noun',
#   '잘/VerbPrefix',
#   '할거/Verb',
#   '같/Adjective',
#   '애/Noun',
#   '이/Noun',
#   '인간/Noun',
#   '들/Suffix',
#   '인간/Noun',
#   '아님/Adjective',
#   '아니/Adjective',
#   '전/Noun',
#   '아니난/Adjective',
#   '죽게/Verb',
#   '해줘/Verb',
#   '한국/Noun',
#   '교육/Noun',
#   '열/Noun',
#   '제발/Noun',
#   '그만/Adverb',
#   '미세먼지/Noun',
#   '오지는데/Verb',
#   '시/Modifier',
#   '교육청/Noun',
#   '초등학교/Noun',
#   '공기청정기/Noun',
#   '주고/Verb',
#   '중/Noun',
#   '고등학교/Noun',
#   '아직도/Adverb',
#   '공기청정기/Noun',
#   '없어요/Adjective',
#   '“/Foreign',
#   '중국산/Noun',
#   '미세먼지/Noun',
#   '샤오미/Noun',
#   '공기청정기/Noun',
#   '안/VerbPrefix',
#   '돼/Verb',
#   '”/Foreign',
#   '반중/Noun',
#   '불매운동/Noun',
#   '확산/Noun'],
#  ['출처/Noun', '국민일보/Noun', '네이버/Noun'],
#  ['\xa0/Foreign',
#   '시리얼/Noun',
#   '먹구/Verb',
#   '머리/Noun',
#   '말리/Noun',
#   '바로/Noun',
#   '가야/Noun',
#   '얼굴/Noun',
#   '부워/Noun',
#   '얼굴/Noun',
#   '무거/Noun',
#   '웤/Noun',
#   'ㅋㅋ/KoreanParticle'],
#  [],
#  ['그나마/Adverb',
#   '미세먼지/Noun',
#   '좀/Noun',
#   '물러났다고/Verb',
#   '숨쉬기/Noun',
#   '편하게/Adjective',
#   '잤다/Verb',
#   '미쳤어/Adjective',
#   '증말/Noun',
#   '공기청정기/Noun',
#   '사야/Verb',
#   '한다/Verb',
#   '비염/Noun',
#   '인/Suffix',
#   '필수/Noun',
#   '생존/Noun',
#   '템/Noun',
#   '점막/Noun',
#   '손상/Noun',
#   '코피/Noun',
#   '죽는/Verb',
#   '건가/Noun',
#   '출혈/Noun'],
#  [],
#  ['아님/Adjective',
#   '콧구멍/Noun',
#   '혈관/Noun',
#   '어캐/Noun',
#   '검열/Noun',
#   '해야하나/Verb',
#   '넘/Verb',
#   '성가심/Adjective',
#   '택배/Noun',
#   '하는/Verb',
#   '사람/Noun',
#   '입니다/Adjective'],
#  [],
#  ['이번/Noun', '주/Noun', '배달/Noun', '물량중/Noun', '가장/Noun', '많이/Adverb'],
#  ['늘어난/Verb', '제품/Noun', '무엇/Noun', '일까/Verb', '요/Noun'],
#  [],
#  ['제/Noun', '느끼기에/Verb', '가장/Noun', '늘어난건/Verb'],
#  [],
#  ['마스크/Noun', '공기청정기/Noun', '많이/Adverb'],
#  ['늘었습니다/Verb'],
#  [],
#  ['그만큼/Adverb', '미세먼지/Noun', '심각/Noun', '성/Suffix'],
#  ['느끼는/Verb', '분/Noun', '들/Suffix', '많은거겠죠/Adjective'],
#  [],
#  ['시간/Noun', '좀더/Noun', '지나면/Verb', '황사/Noun', '올텐데/Verb'],
#  ['외부/Noun', '일/Noun', '하는/Verb', '분들/Suffix', '건강/Noun'],
#  ['유의/Noun',
#   '하세요/Verb',
#   '박/Noun',
#   '원/Suffix',
#   '숭/Noun',
#   '미세먼지/Noun',
#   '페인트/Noun',
#   '뉴스/Noun',
#   '보니/Verb',
#   '옥상/Noun',
#   '양봉/Noun',
#   '생각나네/Verb',
#   '지긋지긋하다/Adjective',
#   '하긴/Verb',
#   '공기청정기/Noun',
#   '설치/Noun',
#   '하란/Noun',
#   '사람/Noun',
#   '하는/Verb',
#   '짓/Noun',
#   '보면/Verb',
#   '대가리/Noun',
#   '든/Verb',
#   '게/Noun',
#   '없는/Adjective',
#   '게/Noun',
#   '맞는/Verb',
#   '것/Noun',
#   '같다/Adjective'],
#  ['이/Noun',
#   '너른/Noun',
#   '천지/Noun',
#   '공기청정기/Noun',
#   '미세먼지/Noun',
#   '막아/Verb',
#   '낸다니/Verb'],
#  ['상식/Noun', '적/Suffix', '도저히/Noun', '이해/Noun', '되지/Verb', '않는다/Verb'],
#  ['차리/Verb',
#   '그/Noun',
#   '돈/Noun',
#   '모든/Noun',
#   '국민/Noun',
#   '들/Suffix',
#   'KF/Alpha',
#   '마스크/Noun',
#   '배부/Noun',
#   '하는/Verb',
#   '게/Noun',
#   '훨/Noun',
#   '낫/Noun',
#   '않은가/Verb',
#   '국민/Noun',
#   '여러분/Noun',
#   '미세먼지/Noun',
#   '많습니다/Adjective',
#   '방독면/Noun',
#   '사십/Modifier',
#   '쇼/Noun',
#   '공기청정기/Noun',
#   '사십/Modifier',
#   '쇼/Noun',
#   '우리/Noun',
#   '회사/Noun',
#   '더/Noun',
#   '공기청정기/Noun',
#   '있지만/Adjective',
#   '건물/Noun',
#   '나오면/Verb',
#   '미세먼지/Noun',
#   '잔뜩/Noun',
#   '있잖아/Adjective',
#   'ㅋㅋㅋㅋㅋ/KoreanParticle',
#   '그래서/Adverb',
#   '요즘/Noun',
#   '목도/Noun',
#   '안/Noun',
#   '좋고/Adjective',
#   '눈/Noun',
#   '뭔가/Noun',
#   '따가워/Adjective',
#   'ㅋㅋㅋㅋㅋ/KoreanParticle',
#   '나/Noun',
#   '감기/Noun',
#   '두/Noun',
#   '달/Noun',
#   '정도/Noun',
#   '안/Noun',
#   '낫/Noun',
#   '있어/Adjective',
#   '그래도/Adverb',
#   '봄/Noun',
#   '좀/Noun',
#   '나아졌는데/Verb',
#   '겨울/Noun',
#   '너무/Adverb',
#   '힘들었다/Adjective',
#   'ㅋㅋㅋㅋㅋ/KoreanParticle',
#   '애기/Noun',
#   '괜찮아/Adjective',
#   '요즘/Noun',
#   '미세먼지/Noun',
#   '엄청나게/Adjective',
#   '많죠/Adjective',
#   '인천/Noun',
#   '가장/Noun',
#   '많다는데/Adjective',
#   'ㅠㅠ/KoreanParticle',
#   '그래도/Adverb',
#   '학교/Noun',
#   '공기청정기/Noun',
#   '많이/Adverb',
#   '설치/Noun',
#   '해줘서/Verb',
#   '다행/Noun',
#   '미세먼지/Noun',
#   '조심하세요/Verb',
#   'ㅠㅠ/KoreanParticle',
#   '스모그/Noun',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '공기/Noun',
#   '양극화/Noun',
#   '말/Noun',
#   '나오지/Verb',
#   '않도록/Verb',
#   '마스크/Noun',
#   '공기청정기/Noun',
#   '소득공제/Noun',
#   '서둘러야/Verb'],
#  [],
#  ['#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '손바닥/Noun',
#   '해/Noun',
#   '가리나/Verb'],
#  [],
#  ['#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '…#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '자연/Noun',
#   '발생/Noun',
#   '느끼도록/Verb',
#   '만들어진/Verb',
#   '미세먼지/Noun',
#   '말/Noun',
#   '틀렸다/Verb',
#   '이건/Noun',
#   '스모그/Noun'],
#  [],
#  ['#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '미세먼지/Noun',
#   '국민/Noun',
#   '들/Suffix',
#   '드러/Adjective',
#   '누/Noun',
#   '울/Modifier',
#   '판/Noun',
#   '아직도/Adverb',
#   '과거/Noun',
#   '사냐/Verb'],
#  ['무능한/Adjective',
#   '정부/Noun',
#   '때문/Noun',
#   '속/Noun',
#   '하는/Verb',
#   '사람/Noun',
#   '많다/Adjective',
#   '그런데/Conjunction',
#   '민심/Noun',
#   '뉴스/Noun',
#   '보도/Noun',
#   '하/Suffix',
#   '지지율/Noun',
#   '반대/Noun',
#   '가니/Verb',
#   '좀/Noun',
#   '이상하다/Adjective',
#   '아무래도/Adverb',
#   'ᆢ/Foreign'],
#  ['ㅡㅡㅡㅡㅡㅡ/KoreanParticle'],
#  ['거리/Noun',
#   '대형/Noun',
#   '공기청정기/Noun',
#   '쏟아지는/Verb',
#   '대책/Noun',
#   '실효/Noun',
#   '성/Suffix',
#   '있나/Adjective',
#   '출처/Noun',
#   'SBS/Alpha',
#   '네이버/Noun',
#   '뉴스/Noun',
#   '\xa0/Foreign',
#   '출연/Noun',
#   '쿠쿠/Noun',
#   '대/Modifier',
#   '유위/Noun',
#   '니아/Noun',
#   '공기청정기/Noun',
#   '수요/Noun',
#   '상반기/Noun',
#   '호실/Noun',
#   '적/Suffix',
#   '예고/Noun',
#   '미세먼지/Noun',
#   '특수/Noun',
#   '\xa0/Foreign',
#   '이건/Noun',
#   '진짜/Noun',
#   '오늘/Noun',
#   '내/Noun',
#   '힐링/Noun',
#   '영상/Noun',
#   '리스트/Noun',
#   '추가/Noun',
#   '아까/Adjective',
#   '혐생/Noun',
#   '중/Noun',
#   '보고/Noun',
#   '나도/Verb',
#   '모르게/Verb',
#   '개/Noun',
#   '저/Determiner',
#   '웃음/Noun',
#   '지음/Noun',
#   '찍는거/Verb',
#   '보고/Noun',
#   '정색/Noun',
#   '하기/Verb',
#   '전/Noun',
#   '완전/Noun',
#   '무장해제/Noun',
#   '웃음/Noun',
#   '짓는/Verb',
#   '텐/PreEomi',
#   '보고/Noun',
#   '미세먼지/Noun',
#   '뒤덮힌/Verb',
#   '몸/Noun',
#   '마음/Noun',
#   '싹/Noun',
#   '정화/Noun',
#   '됐다/Verb',
#   '공기청정기/Noun',
#   '다/Adverb',
#   '무슨/Noun',
#   '필요/Noun',
#   '이/Noun',
#   '영상/Noun',
#   '하나/Noun',
#   '새/Noun',
#   '사람/Noun',
#   '된다/Verb',
#   '공기청정기/Noun',
#   '제습기/Noun',
#   '가습기/Noun',
#   '스타/Noun',
#   '일러/Verb',
#   '미세먼지/Noun',
#   '제거/Noun',
#   '용/Noun',
#   '에어컨/Noun',
#   '난/Noun',
#   '방기/Noun',
#   '정도/Noun',
#   '갖춰야/Verb',
#   '윤택/Noun',
#   '삶/Noun',
#   '될/Verb',
#   '수/Noun',
#   '있다는/Adjective',
#   '거/Noun',
#   '너무/Adverb',
#   '슬프다/Adjective',
#   '그렇게/Adverb',
#   '싫으면/Adjective',
#   '나가/Verb',
#   '살/Noun',
#   '가/Verb',
#   '등신/Noun',
#   '미세먼지/Noun',
#   '어제/Noun',
#   '오늘/Noun',
#   '일도/Noun',
#   '아니고/Adjective',
#   '중국/Noun',
#   '항의/Noun',
#   '하면/Verb',
#   '미세먼지/Noun',
#   '없어지냐/Verb',
#   '미세먼지/Noun',
#   '40/Number',
#   '퍼센트/Noun',
#   '기레기/Noun',
#   '들/Suffix',
#   '허풍/Noun',
#   '거/Noun',
#   '몰라/Verb',
#   '공기청정기/Noun',
#   '같은/Adjective',
#   '광고/Noun',
#   '만들려고/Verb',
#   '공/Modifier',
#   '포심/Noun',
#   '조장/Noun',
#   '하는/Verb',
#   '아주/Noun',
#   '미세먼지/Noun',
#   '못/Noun',
#   '인간/Noun',
#   '일세/Verb',
#   '\xa0/Foreign',
#   '요즘/Noun',
#   '공기청정기/Noun',
#   '제/Modifier',
#   '조사/Noun',
#   '•/Foreign',
#   '판매/Noun',
#   '업자/Noun',
#   '들/Suffix',
#   '미세먼지/Noun',
#   '너무/Adverb',
#   '사랑/Noun',
#   '않을까/Verb',
#   '함/Noun',
#   '공기청정기/Noun',
#   '마스크/Noun',
#   '난/Noun',
#   '필요없다/Adjective',
#   '극한/Noun',
#   '미세먼지/Noun',
#   '속/Noun',
#   '청량한/Adjective',
#   '동스청/Noun',
#   '알/Noun',
#   '미세먼지/Noun',
#   '함께/Adverb',
#   '하던/Verb',
#   '지난/Noun',
#   '일주일/Noun',
#   '간의/Noun',
#   '등교/Noun',
#   '로/Noun',
#   '쌓/Verb',
#   '엿/Modifier',
#   '던/Noun',
#   '스트레스/Noun',
#   '다/Adverb',
#   '날아가/Verb',
#   '버렷/Noun',
#   '네/Suffix',
#   '슈짐/Noun',
#   '나/Noun',
#   '공기청정기/Noun',
#   '야자/Noun',
#   '할/Verb',
#   '때/Noun',
#   'ㄹㅇ/KoreanParticle',
#   '응원/Noun',
#   '컵/Noun',
#   '미세먼지/Noun',
#   '속/Noun',
#   '청정/Noun',
#   '공기청정기/Noun',
#   '역할/Noun',
#   '동기부여/Noun',
#   '짠/Verb',
#   'ㅁ/KoreanParticle',
#   '장임/Noun',
#   '울/Noun',
#   '태형/Noun',
#   '잉/Noun',
#   '나가지말고/Verb',
#   '숨겨야/Verb',
#   '돼/Verb',
#   '미세먼지/Noun',
#   '마시면/Verb',
#   '안/VerbPrefix',
#   '돼/Verb',
#   'ㅠㅠ/KoreanParticle',
#   '집/Noun',
#   '공기청정기/Noun',
#   '틀어놓고/Verb',
#   '연탄/Noun',
#   '놀/Foreign',
#   '\xa0/Foreign',
#   '미세먼지/Noun',
#   '죽을래/Verb',
#   '이산화탄소/Noun',
#   '죽을래/Verb',
#   '미세먼지/Noun',
#   '죽을래/Verb',
#   '방사/Noun',
#   '능/Noun',
#   '죽을래/Verb',
#   '어차피/Noun',
#   '다/Adverb',
#   '죽게/Verb',
#   '되어있다/Verb',
#   '공기청정기/Noun',
#   '장사/Noun',
#   '들/Suffix',
#   '노/Noun',
#   '났네/Verb',
#   '나중/Noun',
#   '가습기/Noun',
#   '문제/Noun',
#   '되는/Verb',
#   '일/Noun',
#   '없게/Adjective',
#   '해/Noun',
#   '태양광/Noun',
#   '공기청정기/Noun',
#   '숲/Noun',
#   '사라지는/Verb',
#   '건/Noun',
#   '미세먼지/Noun',
#   '대기오염/Noun',
#   '와/Verb',
#   '상관/Noun',
#   '없는/Adjective',
#   '일일/Noun',
#   '까/Verb',
#   '아아/Noun',
#   '사립/Noun',
#   '외쳐/Verb',
#   '갓/Noun',
#   '사립/Noun',
#   '공기청정기/Noun',
#   '쾌적한/Adjective',
#   '실내/Noun',
#   '환경/Noun',
#   '미세먼지/Noun',
#   '흡입/Noun',
#   '시발/Noun',
#   '이/Suffix',
#   '뭔/Modifier',
#   '일이/Noun',
#   '진짜/Noun',
#   '세상/Noun',
#   '난리/Noun',
#   '났다/Verb',
#   '난리/Noun',
#   '민윥기/Noun',
#   '가나/Noun',
#   '나라/Noun',
#   '민윥기/Noun',
#   '이/Determiner',
#   '각박/Noun',
#   '한세상/Noun',
#   '윥기너/Noun',
#   '하나로/Noun',
#   '버틴다내가/Verb',
#   '진짜/Noun',
#   '미세먼지/Noun',
#   '필요없어/Adjective',
#   '너/Noun',
#   '하/Suffix',
#   '나면/Verb',
#   '공기청정기/Noun',
#   '오조오억/Noun',
#   '개/Suffix',
#   '돌리는/Verb',
#   '느낌/Noun',
#   '윥기/Noun',
#   '진짜/Noun',
#   '주접/Noun',
#   '이아/Noun',
#   '니아/Noun',
#   '사실/Noun',
#   '생일/Noun',
#   '축하/Noun',
#   '해말랑/Verb',
#   '뽀짝/Noun',
#   '태어나줘서/Verb',
#   '고마워/Adjective',
#   '공기청정기/Noun',
#   '틀/Noun',
#   '창문/Noun',
#   '꽉/Noun',
#   '이산화탄소/Noun',
#   '‘/Foreign',
#   '숨/Noun',
#   '막히는/Verb',
#   '교실/Noun',
#   'KBS/Alpha',
#   '뉴스/Noun',
#   'News/Alpha'],
#  [],
#  ['“/Foreign',
#   '최근/Noun',
#   '뉴스/Noun',
#   '보면/Verb',
#   '공기조화/Noun',
#   '설비/Noun',
#   '갖춰도/Verb',
#   '미세먼지/Noun',
#   '대응/Noun',
#   '하는데/Verb',
#   '한계/Noun',
#   '있다고/Adjective',
#   '했지만/Verb',
#   '환기/Noun',
#   '위해/Noun',
#   '외/Noun',
#   '기를/Verb',
#   '일부/Noun',
#   '도입/Noun',
#   '내부/Noun',
#   '내기/Noun',
#   '일부/Noun',
#   '리턴/Noun',
#   '하여/Verb',
#   '적절한/Adjective',
#   '수준/Noun',
#   '유지/Noun',
#   '하는/Verb',
#   '것/Noun',
#   '메인/Noun',
#   '”/Foreign'],
#  [],
#  ['\xa0/Foreign',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ/KoreanParticle',
#   '애기/Noun',
#   '언니/Noun',
#   '맴/Noun',
#   '조지/Noun',
#   '흔드/Noun',
#   'ㅠ/KoreanParticle',
#   '살/Noun',
#   '앙해/Adjective',
#   '내/Noun',
#   '수명/Noun',
#   '니/Noun',
#   '연장/Noun',
#   '시킨다/Verb',
#   '야/Exclamation',
#   '마스크/Noun',
#   '공기청정기/Noun',
#   '둬야겠다/Verb',
#   '사실/Noun',
#   '얼른/Noun',
#   '미세먼지/Noun',
#   '흡수/Noun',
#   '수명/Noun',
#   '깎을/Verb',
#   '생각/Noun',
#   '이/Determiner',
#   '엇어/Noun',
#   '나/Noun',
#   '항뇬/Noun',
#   '그리고/Conjunction',
#   '독/Noun',
#   '마님/Noun',
#   '있어/Adjective',
#   '미세먼지/Noun',
#   '공기청정기/Noun',
#   '됩니다/Verb',
#   '나/Noun',
#   '나/Noun',
#   '요즘/Noun',
#   '미세먼지/Noun',
#   '너무/Adverb',
#   '심해서/Adjective',
#   '공기청정기/Noun',
#   '좋더라/Adjective',
#   '하나/Noun',
#   '사서/Noun',
#   '집/Noun',
#   '두/Determiner',
#   '려고/Noun',
#   '정말/Noun',
#   '민윤기/Noun',
#   '보고/Noun',
#   '너무/Adverb',
#   '귀여워서/Adjective',
#   '미세먼지/Noun',
#   '돌아가겠다/Verb',
#   '인간/Noun',
#   '공기청정기/Noun',
#   '지정/Noun',
#   '해야/Verb',
#   '돼/Verb',
#   '성영/Noun',
#   '세계관/Noun',
#   '미세먼지/Noun',
#   '있을까/Adjective',
#   'ㄷ/KoreanParticle',
#   '공기청정기/Noun',
#   '능력/Noun',
#   '소유자/Noun',
#   '한/Determiner',
#   '명/Noun',
#   '쯤/Suffix',
#   '있지/Adjective',
#   '않을까/Verb',
#   '공기청정기/Noun',
#   '필요한가요/Adjective',
#   '집안/Noun',
#   '공기/Noun',
#   '정화/Noun',
#   '하는게/Verb',
#   '의미/Noun',
#   '있을까/Adjective',
#   '싶어서요/Verb',
#   '사람/Noun',
#   '집안/Noun',
#   '살/Noun',
#   '수/Noun',
#   '있는게/Adjective',
#   '아닌데/Adjective',
#   '나가면/Verb',
#   '어찌/Noun',
#   '피/Noun',
#   '미세먼지/Noun',
#   '그대로/Noun',
#   '마시는데/Verb',
#   '—/Foreign',
#   '필요해요/Adjective',
#   '\xa0/Foreign',
#   '상규/Noun',
#   '머/Noun',
#   '하구/Verb',
#   '지낼까/Verb',
#   '하늘/Noun',
#   '미세먼지/Noun',
#   '그득그득/Adverb',
#   '한/Determiner',
#   '데/Noun',
#   '공기청정기/Noun',
#   '들여다/Verb',
#   '놨는/Noun',
#   '맛있는/Adjective',
#   '거/Noun',
#   '잔뜩/Noun',
#   '먹구/Verb',
#   '있는지/Adjective',
#   '컴백/Noun',
#   '준비/Noun',
#   '바빠서/Adjective',
#   '밥/Noun',
#   '안/Noun',
#   '챙겨/Verb',
#   '먹고/Verb',
#   '연습/Noun',
#   '하는건/Verb',
#   '아닌지/Adjective',
#   '미세먼지/Noun',
#   '심해/Noun',
#   '작은/Adjective',
#   '탐정/Noun',
#   '군/Suffix',
#   '아플까봐/Adjective',
#   '걱정/Noun',
#   '된/Verb',
#   '아무로/Noun',
#   '군/Suffix',
#   '탐정/Noun',
#   '군/Suffix',
#   '위/Noun',
#   '공기청정기/Noun',
#   '구매/Noun',
#   '했습니다/Verb',
#   '이제/Noun',
#   '코난/Noun',
#   '군/Suffix',
#   '아프지/Adjective',
#   '않겠지요/Verb',
#   '포/Noun',
#   '와로/Noun',
#   '기다릴게요/Verb',
#   'ㅋㅋㅋㅋㅋㅋㅋ/KoreanParticle',
#   '존나/Noun',
#   '룸메/Noun',
#   '말/Noun',
#   '안통/Noun',
#   '하/Suffix',
#   '공기청정기/Noun',
#   '오존/Noun',
#   '나와서/Verb',
#   '싫다고만/Adjective',
#   '하면/Verb',
#   '뭐/Noun',
#   '어쩌라고/Adverb',
#   '155/Number',
#   '창문/Noun',
#   '열고/Verb',
#   '싶냐/Verb',
#   '미세먼지/Noun',
#   '맡다가/Verb',
#   '뒤지겠네/Verb',
#   '시발/Noun',
#   '오빠/Suffix',
#   '공기청정기/Noun',
#   '필터/Noun',
#   '도착/Noun',
#   '해서/Verb',
#   '갈아/Adverb',
#   '끼운/Verb',
#   '기념/Noun',
#   '미세먼지/Noun',
#   '심해지길/Verb',
#   '바랄/Verb',
#   '수도/Noun',
#   '없구/Adjective',
#   '그렇다고/Conjunction',
#   '미세먼지/Noun',
#   '나아지/Verb',
#   '자니/Verb',
#   '늦게/Verb',
#   '도착/Noun',
#   '필터/Noun',
#   '원망/Noun',
#   '스럽고/Adjective',
#   '아니다/Adjective',
#   '그냥/Noun',
#   '늦게/Verb',
#   '온/Noun',
#   '필터/Noun',
#   '잘/VerbPrefix',
#   '못/VerbPrefix',
#   '한거져/Verb',
#   '부천시/Noun',
#   '봄철/Noun',
#   '‘/Foreign',
#   '미세먼지/Noun',
#   '저/Determiner',
#   '감/Noun',
#   '대책/Noun',
#   '추진/Noun',
#   '살수차/Noun',
#   'ㆍ/Foreign',
#   '분진/Noun',
#   '흡입/Noun',
#   '차량/Noun',
#   '운영/Noun',
#   '시간/Noun',
#   '확대/Noun',
#   '경로당/Noun',
#   '등/Noun',
#   '공기청정기/Noun',
#   '590/Number',
#   '대/Verb',
#   '운영/Noun',
#   '지역/Noun',
#   '동/Modifier',
#   '세터/Noun',
#   '마스크/Noun',
#   '18만/Number',
#   '매/Foreign',
#   '보급/Noun',
#   '\xa0/Foreign'],
#  ['#더부천/Hashtag',
#   '#thebucheon부천시/Hashtag',
#   '봄철/Noun',
#   '‘/Foreign',
#   '미세먼지/Noun',
#   '저/Determiner',
#   '감/Noun',
#   '대책/Noun',
#   '추진/Noun',
#   '살수차/Noun',
#   'ㆍ/Foreign',
#   '분진/Noun',
#   '흡입/Noun',
#   '차량/Noun',
#   '운영/Noun',
#   '시간/Noun',
#   '확대/Noun',
#   '경로당/Noun',
#   '등/Noun',
#   '공기청정기/Noun',
#   '590/Number',
#   '대/Verb',
#   '운영/Noun',
#   '지역/Noun',
#   '동/Modifier',
#   '세터/Noun',
#   '마스크/Noun',
#   '18만/Number',
#   '매/Foreign',
#   '보급/Noun',
#   '\xa0/Foreign'],
#  ['#더부천/Hashtag',
#   '#thebucheon부천시/Hashtag',
#   '봄철/Noun',
#   '‘/Foreign',
#   '미세먼지/Noun',
#   '저/Determiner',
#   '감/Noun',
#   '대책/Noun',
#   '추진/Noun',
#   '살수차/Noun',
#   'ㆍ/Foreign',
#   '분진/Noun',
#   '흡입/Noun',
#   '차량/Noun',
#   '운영/Noun',
#   '시간/Noun',
#   '확대/Noun',
#   '경로당/Noun',
#   '등/Noun',
#   '공기청정기/Noun',
#   '590/Number',
#   '대/Verb',
#   '운영/Noun',
#   '지역/Noun',
#   '동/Modifier',
#   '세터/Noun',
#   '마스크/Noun',
#   '18만/Number',
#   '매/Foreign',
#   '보급/Noun',
#   '\xa0/Foreign'],
#  ['#더부천/Hashtag',
#   '#thebucheon영배오빠/Hashtag',
#   '작업실/Noun',
#   '미세먼지/Noun',
#   '다/Adverb',
#   '없애/Verb',
#   '조/Noun',
#   '공기청정기/Noun',
#   '네/Noun',
#   '안/Noun',
#   '그래도/Adverb',
#   '아까/Adjective',
#   '나가서/Verb',
#   '감기/Noun',
#   '약/Noun',
#   '한번/Noun',
#   '더/Noun',
#   '사와서/Verb',
#   '죽/Noun',
#   '먹고/Verb',
#   '약/Noun',
#   '먹었어요/Verb',
#   '´/Foreign'],
#  ['정말/Noun',
#   '미세먼지/Noun',
#   '심하다고/Adjective',
#   '해서/Verb',
#   '이렇게/Adverb',
#   '될줄은/Verb',
#   '몰랐는데/Verb',
#   '제/Noun',
#   '목/Noun',
#   '많이/Adverb',
#   '약하긴/Adjective',
#   '한/Verb',
#   '가봐요/Verb',
#   'ㅠㅠㅠㅋㅋㅋㅋㅋㅠㅠ/KoreanParticle'],
#  ['진자/Noun',
#   '중국/Noun',
#   '미세먼지/Noun',
#   '어케/Noun',
#   '해야하구/Verb',
#   'ㅠㅠ/KoreanParticle'],
#  ['공기청정기/Noun',
#   '넘/Verb',
#   '비싸고/Adjective',
#   '고민/Noun',
#   '되네요/Verb',
#   '와/Verb',
#   '근데/Adverb',
#   '이제/Noun',
#   '반장/Noun',
#   '선거/Noun',
#   '공약/Noun',
#   '미세먼지/Noun',
#   '나오기/Verb',
#   '시작/Noun',
#   '함/Noun'],
#  ['우리/Noun',
#   '반/Noun',
#   '미세먼지/Noun',
#   '책임지고/Verb',
#   '없애겠습니다/Verb',
#   '공기청정기/Noun',
#   '제/Noun',
#   '관리/Noun',
#   '하겠/Verb',
#   '슴/Noun',
#   '다/Adverb',
#   'ㄱㅇㄱ/KoreanParticle',
#   '미세먼지/Noun',
#   '같은/Adjective',
#   '이번/Noun',
#   '주의/Noun',
#   '기분/Noun',
#   '상쾌하게/Adjective',
#   '만들어/Verb',
#   '준/Noun',
#   '공기청정기/Noun',
#   '같은/Adjective',
#   '기범이/Noun',
#   '폴라로이드/Noun'],
#  ['#샤이니/Hashtag',
#   '#키/Hashtag',
#   '#SHINee/Hashtag',
#   '#KEY/Hashtag',
#   '#기범/Hashtag',
#   '#IWannaBe/Hashtag',
#   '#IWannaBePolar/Hashtag',
#   '#폴라로이드/Hashtag',
#   '#polaroid/Hashtag',
#   '@IWannaBePolarpic/ScreenName',
#   '피스/Noun',
#   '넷/Noun',
#   '미세먼지/Noun',
#   '공기청정기/Noun',
#   '공기청정기/Noun',
#   '추천/Noun',
#   '피스/Noun',
#   '넷/Noun',
#   '퓨어/Noun',
#   '360/Number'],
#  [],
#  ['진짜/Noun',
#   '가격/Noun',
#   '대비/Noun',
#   '이런/Adjective',
#   '공기청정기/Noun',
#   '없습니다/Adjective',
#   '고민/Noun',
#   '하지말고/Verb',
#   '바로/Noun',
#   '구매/Noun',
#   '하세요/Verb',
#   '1/Number',
#   '단계/Noun',
#   '제/Noun',
#   '기준/Noun',
#   '거의/Noun',
#   '무/Noun',
#   '소음/Noun',
#   '입니다/Adjective',
#   '전/Noun',
#   '그냥/Noun',
#   '1/Number',
#   '단계/Noun',
#   '계속/Noun',
#   '켜/Noun',
#   '네/Determiner',
#   '욤/Noun',
#   '강/Noun',
#   '추합니다/Adjective',
#   '공기청정기/Noun',
#   '샀당/Verb',
#   '돈/Noun',
#   '조금/Noun',
#   '들었지만/Verb',
#   '얼마/Noun',
#   '전/Noun',
#   '최악/Noun',
#   '미세먼지/Noun',
#   '겪고/Verb',
#   '사야겠단/Verb',
#   '생각/Noun',
#   '궁극/Noun',
#   '적/Suffix',
#   '기후변화/Noun',
#   '영향/Noun',
#   '적은/Verb',
#   '살/Noun',
#   '만/Suffix',
#   '곳/Noun',
#   '도망치는/Verb',
#   '게/Noun',
#   '목표/Noun',
#   '입니다만/Adjective',
#   '일단/Noun',
#   '그때/Noun',
#   '건강해야/Adjective',
#   '하지/Verb',
#   '않겠느냐고/Verb'],
#  ['나/Noun',
#   '별것/Noun',
#   '안/VerbPrefix',
#   '했는데/Verb',
#   '혼자/Noun',
#   '계속/Noun',
#   '주황색/Noun',
#   '파란색/Noun',
#   '넘나/Verb',
#   '드시는/Verb',
#   '중이/Noun',
#   '요즘/Noun',
#   '공기청정기/Noun',
#   '미세먼지/Noun',
#   '경보/Noun',
#   '발령/Noun',
#   '하면/Verb',
#   '알아서/Verb',
#   '전원/Noun',
#   '켜진다고/Verb',
#   '나/Noun',
#   '낫/Noun',
#   '정부/Noun',
#   '올해/Noun',
#   '안/Noun',
#   '모든/Noun',
#   '#학교/Hashtag',
#   '교실/Noun',
#   '#공기청정기/Hashtag',
#   '를/Noun',
#   '설치/Noun',
#   '하겠다고/Verb',
#   '발표/Noun',
#   '했는데요/Verb',
#   '얼마나/Noun',
#   '효과/Noun',
#   '있을까요/Adjective',
#   '공기청정기/Noun',
#   '있는/Adjective',
#   '교실/Noun',
#   '공기/Noun',
#   '질/Noun',
#   '측정/Noun',
#   '해봤더니/Verb',
#   '미세먼지/Noun',
#   '줄었지만/Verb',
#   '대신/Noun',
#   '#이산화탄소/Hashtag',
#   '농도/Noun',
#   '높아졌습니다/Verb',
#   '\xa0/Foreign',
#   '미세먼지/Noun',
#   '줄어드니까/Verb',
#   '확실히/Adjective',
#   '공기청정기/Noun',
#   '많이/Adverb',
#   '조용하다/Adjective',
#   '아니/Adjective',
#   '공기청정기/Noun',
#   '수치/Noun',
#   '왜/Noun',
#   '미세먼지/Noun',
#   '어제/Noun',
#   '심하지/Adjective',
#   '않았었나/Verb',
#   '어젠/Noun',
#   '괜찮/Adjective',
#   '더/Noun',
#   '저/Determiner',
#   '아까/Adjective',
#   '바보/Noun',
#   '같은/Adjective',
#   '뉴스/Noun',
#   '봤는데/Verb',
#   '겨실에/Verb',
#   '공기청정기/Noun',
#   '을/Noun',
#   '설치/Noun',
#   'ㅠ/KoreanParticle',
#   '변화/Noun',
#   '지켜봤더니/Verb',
#   '미세먼지/Noun',
#   '줄었는데/Verb',
#   '이산화탄소/Noun',
#   '늘어났다고/Verb',
#   '했잖아요/Verb',
#   '설마/Noun',
#   '이/Determiner',
#   '거/Noun',
#   '학생/Noun',
#   '들/Suffix',
#   '안/Noun',
#   '있는/Adjective',
#   '교실/Noun',
#   '측정/Noun',
#   '한/Determiner',
#   '건가/Noun'],
#  ['그럼/Adjective',
#   '사람/Noun',
#   '만든/Verb',
#   '이산화탄소/Noun',
#   '공/Modifier',
#   '기/Modifier',
#   '창/Noun',
#   '정기/Noun',
#   '만든/Verb',
#   '이산화탄소/Noun',
#   '오해/Noun',
#   '하잖아안이/Verb',
#   '제/Noun',
#   '공기청정기/Noun',
#   '엿/Modifier',
#   '으/Noun',
#   '진작/Noun',
#   '탐라/Noun',
#   '미세먼지/Noun',
#   '제로/Noun',
#   '클린/Noun',
#   '탐라/Noun',
#   '엿/Modifier',
#   '겟/Noun'],
#  [],
#  ['그리구/Verb',
#   '장/Noun',
#   '도담/Noun',
#   '당신/Noun',
#   '웃는/Verb',
#   '모습/Noun',
#   '라면/Noun',
#   '뭐/Noun',
#   '예뻐요/Adjective',
#   '멋/Noun',
#   '잇는/Verb',
#   'ㅡ/KoreanParticle',
#   '말투/Noun',
#   'ㅡ/KoreanParticle',
#   '로/Noun',
#   'ㅡ/KoreanParticle',
#   '국방부/Noun',
#   '#미세먼지/Hashtag',
#   '로부터/Noun',
#   '장병/Noun',
#   '들/Suffix',
#   '건강/Noun',
#   '보호/Noun',
#   '하기/Verb',
#   '위해/Noun',
#   '오늘/Noun',
#   '8일/Number',
#   '부터/Noun',
#   '각/Noun',
#   '부대/Noun',
#   '병영/Noun',
#   '생활관/Noun',
#   '#공기청정기/Hashtag',
#   '를/Noun',
#   '보급/Noun',
#   '하기/Verb',
#   '시작/Noun',
#   '했습니다/Verb',
#   '\xa0/Foreign',
#   '공구/Noun',
#   '플러스/Noun',
#   '2019년/Number',
#   '03월/Number',
#   '05일/Number',
#   '두번째/Noun',
#   '최저/Noun',
#   '공동/Noun',
#   '구매/Noun',
#   '상품/Noun',
#   '1/Number',
#   '미세먼지/Noun',
#   '리무/Noun',
#   '버크/Noun',
#   '림/Noun',
#   '2/Number',
#   '하/Exclamation',
#   '이드/Noun',
#   '로마/Noun',
#   '공기청정기/Noun',
#   '3/Number',
#   '탁/Noun',
#   '터키/Noun',
#   '시/Modifier',
#   '워/Noun',
#   '내/Determiner',
#   '손/Noun',
#   '마사지/Noun',
#   '기/Noun',
#   '4/Number',
#   '크레이지/Noun',
#   '립/Noun',
#   '에센스/Noun',
#   '타투/Noun',
#   '5/Number',
#   '모션/Noun',
#   '인식/Noun',
#   '무선충전거치/Foreign',
#   '\xa0/Foreign',
#   '야/Exclamation',
#   '미세먼지/Noun',
#   '조심/Noun',
#   '하/Suffix',
#   '할거면/Verb',
#   '우리/Noun',
#   '집/Noun',
#   '공기청정기/Noun',
#   '보내/Verb',
#   '주/Noun',
#   '학/Noun',
#   '연아/Noun',
#   '공기청정기/Noun',
#   '주변/Noun',
#   '있어/Adjective',
#   '미세먼지/Noun',
#   '많이/Adverb',
#   '마시지말구/Verb',
#   'ㅠㅠㅠㅠㅠㅠㅜ/KoreanParticle',
#   '정부/Noun',
#   '언론/Noun',
#   '미세먼지/Noun',
#   '솔루션/Noun',
#   '요약/Noun',
#   '하자면/Verb',
#   '공기청정기/Noun',
#   '보급/Noun',
#   '경/Modifier',
#   '유차/Noun',
#   '감축/Noun',
#   '전기차/Noun',
#   '보급/Noun',
#   '그러고/Adjective',
#   '보니/Verb',
#   '삼성/Noun',
#   '현대/Noun',
#   '먹거리/Noun',
#   '구마/Noun',
#   '잉/Noun',
#   '미세먼지/Noun',
#   '심하다고/Adjective',
#   '해도/Noun',
#   '마스크/Noun',
#   '안스/Noun',
#   '공기청정기/Noun',
#   '안/VerbPrefix',
#   '사고/Verb',
#   '살다가/Verb',
#   '요/Modifier',
#   '번/Noun',
#   '아주/Noun',
#   '몸/Noun',
#   '제대로/Noun',
#   '체감/Noun',
#   '바리바리/Adverb',
#   '사들이고/Verb',
#   '있다/Adjective'],
#  ['돈/Noun',
#   '없으면/Adjective',
#   '서럽다/Verb',
#   '서러워/Adjective',
#   '이번/Noun',
#   '미세먼지/Noun',
#   '없애라고/Verb',
#   '분무기/Noun',
#   '산/Noun',
#   '우리/Noun',
#   '학교/Noun',
#   '과학/Noun',
#   '쌤/Noun',
#   '학생/Noun',
#   '들/Suffix',
#   '걱정/Noun',
#   '해서/Verb',
#   '공기청정기/Noun',
#   '하나/Noun',
#   '사비/Noun',
#   '사서/Noun',
#   '놨다/Noun',
#   '하루/Noun',
#   '철거/Noun',
#   '하게/Verb',
#   '한/Verb',
#   '전적/Noun',
#   '있습니다/Adjective',
#   '학교/Noun',
#   '교실/Noun',
#   '공기청정기/Noun',
#   '시급하다/Adjective'],
#  ['창원시/Noun', '진해/Noun', '안청/Noun', '초등학교/Noun'],
#  [],
#  ['미세먼지/Noun',
#   '때문/Noun',
#   '아이/Noun',
#   '들/Suffix',
#   '코/Noun',
#   '고름/Noun',
#   'ㅜㅜ/KoreanParticle',
#   '이/Noun',
#   '말/Noun',
#   '이/Suffix',
#   '여름/Noun',
#   '이/Noun',
#   '미세먼지/Noun',
#   '지옥/Noun',
#   '보내야/Verb',
#   '한다고/Verb',
#   '생각/Noun',
#   '하면/Verb',
#   '살기/Noun',
#   '싫어/Adjective',
#   '지는/Verb',
#   '거/Noun',
#   '닥치고/Noun',
#   '실내/Noun',
#   '에어컨/Noun',
#   '공기청정기/Noun',
#   '24시간/Number',
#   '풀/Noun',
#   '가동/Noun',
#   '하는/Verb',
#   '것/Noun',
#   '외/Noun',
#   '대책/Noun',
#   '없는/Adjective',
#   '건데/Eomi',
#   '전기/Noun',
#   '요금/Noun',
#   '누진세/Noun',
#   '없애라/Verb',
#   '도롱/Noun',
#   '놈/Noun',
#   '들/Suffix',
#   '\xa0/Foreign',
#   '미세먼지/Noun',
#   '얘기/Noun',
#   '듣고/Verb',
#   '사/Noun',
#   '생각난건데/Verb',
#   '미세먼지/Noun',
#   '진짜/Noun',
#   '심해서/Adjective',
#   '마스크/Noun',
#   '끼/Noun',
#   '반/Noun',
#   '수업/Noun',
#   '듣는데/Verb',
#   '체육/Noun',
#   '쌤/Noun',
#   '마스크/Noun',
#   '벗으라고/Verb',
#   '그랬다/Adjective'],
#  [],
#  ['그/Determiner',
#   '쌤/Noun',
#   '학교/Noun',
#   '너희/Noun',
#   '집/Noun',
#   '같은/Adjective',
#   '곳/Noun',
#   '너넨/Noun',
#   '집/Noun',
#   '마스크/Noun',
#   '써/Verb',
#   '아니잖아/Adjective',
#   '마스크/Noun',
#   '빼/Noun',
#   '딱/Adverb',
#   '이렇게/Adverb',
#   '말/Noun',
#   '했는데/Verb'],
#  [],
#  ['저희/Modifier',
#   '집/Noun',
#   '공기청정기/Noun',
#   '있는데요/Adjective',
#   '학교/Noun',
#   '없잖아요/Adjective',
#   '울/Modifier',
#   '집/Noun',
#   '공기청정기/Noun',
#   '이틀/Noun',
#   '째/Suffix',
#   '3/Number',
#   '단계/Noun',
#   '집/Noun',
#   '마스크/Noun',
#   '껴야되/Verb',
#   '나/Noun'],
#  ['들숨/Noun',
#   '미세먼지/Noun',
#   '날숨/Noun',
#   '미세먼지/Noun',
#   '마시는/Verb',
#   '이/Determiner',
#   '기분/Noun',
#   '미세먼지/Noun',
#   '심할/Adjective',
#   '때/Noun',
#   '대중교통/Noun',
#   '이용/Noun',
#   '하/Suffix',
#   '한다면/Verb',
#   '대중교통/Noun',
#   '안/Noun',
#   '공기청정기/Noun',
#   '달아줘/Verb',
#   '개철/Noun',
#   '없는/Adjective',
#   '소리/Noun',
#   '알/Noun',
#   '버스/Noun',
#   '먼지/Noun',
#   '들어오고/Verb',
#   '고여/Noun',
#   '있다가/Adjective',
#   '문/Noun',
#   '열리면/Verb',
#   '새로운/Adjective',
#   '미세먼지/Noun',
#   '들어오고의/Verb',
#   '반복/Noun',
#   '잖아/Verb',
#   '코미디/Noun',
#   '韓/Foreign',
#   '언론/Noun',
#   '들/Suffix'],
#  [],
#  ['1/Number', '미세먼지/Noun', '다/Adverb', '中國/Foreign', '탓/Noun'],
#  [],
#  ['2/Number',
#   '車/Foreign',
#   '규제/Noun',
#   '공장/Noun',
#   '규제/Noun',
#   '하지/Verb',
#   '마라/Adjective'],
#  [],
#  ['3/Number',
#   '공포/Noun',
#   '스럽죠/Adjective',
#   '마스크/Noun',
#   '공기청정기/Noun',
#   '필수/Noun',
#   '→/Foreign',
#   '마스크/Noun',
#   '청정기/Noun',
#   '업계/Noun',
#   '커넥션/Noun'],
#  [],
#  ['4/Number', '정부/Noun', '중국/Noun', '협상/Noun', '잘/Verb', '됨/Verb'],
#  [],
#  ['5/Number',
#   '미세먼지/Noun',
#   '中國/Foreign',
#   '發/Foreign',
#   '증거/Noun',
#   '있음/Adjective',
#   '←/Foreign',
#   '미세먼지/Noun',
#   '중국/Noun',
#   '탓/Noun',
#   '프레임/Noun',
#   '막힐까/Verb',
#   '전전긍긍/Noun',
#   '\xa0/Foreign',
#   '전교/Noun',
#   '우리/Noun',
#   '반/Noun',
#   '6-1/Number',
#   '반/Noun',
#   '행정/Noun',
#   '실/Noun',
#   '교무/Noun',
#   '실만/Noun',
#   '공기청정기/Noun',
#   '설치/Noun',
#   '되있어요/Verb',
#   '와아/Exclamation',
#   'ㅜㅠㅠㅠㅠㅠ/KoreanParticle',
#   '다행/Noun',
#   '내/Noun',
#   'ㅠ/KoreanParticle',
#   '입학/Noun',
#   '할/Verb',
#   '때/Noun',
#   '해/Noun',
#   '이정/Noun',
#   '미세먼지/Noun',
#   '상상/Noun',
#   '못/VerbPrefix',
#   '했는데/Verb',
#   'ㅠㅠㅠㅠㅠㅠㅠ/KoreanParticle',
#   '우어/Noun',
#   '어어/Exclamation',
#   '엉/Exclamation',
#   '미세먼지/Noun',
#   '화분/Noun',
#   '증도/Noun',
#   '끔/Verb',
#   '찍/Noun',
#   '집도/Noun',
#   '좁은데/Adjective',
#   '공기청정기/Noun',
#   '사야하나/Verb',
#   '싶어요/Verb',
#   '국방부/Noun',
#   '#병영생활관/Hashtag',
#   '#공기청정기/Hashtag',
#   '#미세먼지/Hashtag'],
#  ['\xa0/Foreign',
#   'ㅁㅊ/KoreanParticle',
#   'ㅋㅋㅋㅋㅋㅋ/KoreanParticle',
#   '미세먼지/Noun',
#   '땜/Noun',
#   '학원/Noun',
#   '대/Verb',
#   '따/Verb',
#   '큰/Verb',
#   '공기청정기/Noun',
#   '생겼/Verb',
#   '옹/Noun',
#   '배우/Noun',
#   '박보검/Noun',
#   '특유/Noun',
#   '밝은/Verb',
#   '에너지/Noun',
#   '따뜻한/Adjective',
#   '미소/Noun',
#   '깨끗한/Adjective',
#   '공기/Noun',
#   '행복한/Adjective',
#   '삶/Noun',
#   '선사/Noun',
#   '한다는/Modifier',
#   '위/Noun',
#   '닉스/Noun',
#   '공기청정기/Noun',
#   '컨셉/Noun',
#   '잘/Verb',
#   '맞아/Verb',
#   '떨어졌으며/Verb',
#   '사전예약/Noun',
#   '수치/Noun',
#   '빠르게/Adjective',
#   '늘/Noun',
#   '있는/Adjective',
#   '것/Noun',
#   '최근/Noun',
#   '미세먼지/Noun',
#   '저/Determiner',
#   '감/Noun',
#   '조/Modifier',
#   '치가/Noun',
#   '7일/Number',
#   '연속/Noun',
#   '이어지는/Verb',
#   '부분/Noun',
#   '주효/Noun',
#   '시너지/Noun',
#   '역할/Noun',
#   '한/Verb',
#   '것/Noun',
#   '보고/Noun',
#   '있다/Adjective',
#   '”/Foreign',
#   '오늘/Noun',
#   '왜/Noun',
#   '미세먼지/Noun',
#   '좀/Noun',
#   '없나/Adjective',
#   '했더니/Verb',
#   '오빠/Noun',
#   '토르/Noun',
#   '산책/Noun',
#   '나와서/Verb',
#   'ㅠㅠㅠㅠ/KoreanParticle',
#   '밋셉먼/Noun',
#   '걸러/Verb',
#   '주는/Verb',
#   '유니/Noun',
#   '저/Noun',
#   '이/Noun',
#   '공기청정기/Noun',
#   '살래요/Verb',
#   'JTBC/Alpha',
#   '는/Verb',
#   '삼성/Noun',
#   '공기청정기/Noun',
#   '홍보/Noun',
#   '담당/Noun',
#   '회사/Noun',
#   '화장지/Noun',
#   '코/Noun',
#   '풀어도/Verb',
#   '미세먼지/Noun',
#   '타령/Noun',
#   '하게/Verb',
#   '생겼으니/Verb',
#   '손석희/Noun',
#   '몸뚱아리/Noun',
#   '묻은/Verb',
#   '더러운/Adjective',
#   '먼지/Noun',
#   '잘/Verb',
#   '터시/Noun',
#   '쓰레기/Noun',
#   '방송/Noun',
#   '\xa0/Foreign',
#   '…#우리_이제_제발_그만만나_미세먼지야/Hashtag'],
#  ['롯데/Noun',
#   '하이마트/Noun',
#   '굿바이/Noun',
#   '미세먼지/Noun',
#   '공기청정기/Noun',
#   '1/Number',
#   '1/Number',
#   '특집/Noun'],
#  ['공기청정기/Noun', '사면/Noun', '공기청정기/Noun', '하나/Noun', '더/Noun'],
#  ['맑은/Noun', '공기/Noun', '두/Determiner', '배/Noun', '마시자/Verb'],
#  ['행사/Noun', '기간/Noun', '3/5/Number', '3/11/Number'],
#  ['모바/Foreign', '\xa0/Foreign'],
#  ['PChttps/Alpha', '://Foreign', '\xa0/Foreign'],
#  ['#롯데하이마트/Hashtag',
#   '#공기청정기/Hashtag',
#   '#미세먼지_그만그런것/Hashtag',
#   '같아요/Adjective',
#   'ㅠㅠㅠ/KoreanParticle',
#   '미세먼지/Noun',
#   '너무/Adverb',
#   '싫어요/Adjective',
#   'ㅠㅠ/KoreanParticle',
#   '공기청정기/Noun',
#   '틀/Noun',
#   '문/Noun',
#   '잠깐/Noun',
#   '열었는데/Verb',
#   '수치/Noun',
#   '100/Number',
#   '은/Noun',
#   '가뿐하게/Adjective',
#   '넘더라구요/Verb',
#   'ㅠㅠ/KoreanParticle',
#   '초등학생/Noun',
#   '들/Suffix',
#   '반/Noun',
#   '하나/Noun',
#   '씩/Suffix',
#   '공기청정기/Noun',
#   '있어서/Adjective',
#   '미세먼지/Noun',
#   '그거/Noun',
#   '4/Number',
#   '나온다던데/Verb',
#   '미세먼지/Noun',
#   '방지/Noun',
#   '실외/Noun',
#   '공기청정기/Noun',
#   '설치/Noun',
#   '하지/Verb',
#   '나무/Noun',
#   '심었으면/Verb',
#   '좋겠어요/Adjective',
#   '미세먼지/Noun',
#   '매우/Noun',
#   '나쁨인데/Adjective',
#   '전교생/Noun',
#   '운동장/Noun',
#   '1시간/Number',
#   '동안/Foreign',
#   '세워놓고/Verb',
#   '입학식/Noun',
#   '한/Determiner',
#   '거/Noun',
#   '무슨/Modifier',
#   '학교/Noun',
#   '우리/Noun',
#   '학교/Noun'],
#  ['그래도/Adverb',
#   '반/Noun',
#   '공기청정기/Noun',
#   '달아놨는데/Verb',
#   '윙윙/Noun',
#   '거리/Noun',
#   '거/Noun',
#   '시끄럽다고/Adjective',
#   '끄라고/Verb',
#   '하는/Verb',
#   '사람/Noun',
#   '누구/Noun',
#   '우리/Noun',
#   '담임/Noun',
#   '군/Noun',
#   '병영/Noun',
#   '생활관/Noun',
#   '공기청정기/Noun',
#   '보급/Noun',
#   '시작/Noun',
#   '“/Foreign',
#   '미세먼지/Noun',
#   '로부터/Noun',
#   '장병/Noun',
#   '건강/Noun',
#   '보호/Noun',
#   '”/Foreign',
#   '\xa0/Foreign',
#   '최악/Noun',
#   '미세먼지/Noun',
#   '대란/Noun',
#   '공기청정기/Noun',
#   '판매량/Noun',
#   '사상/Noun',
#   '최대/Noun',
#   '제발/Noun',
#   'ㅅㅂ/KoreanParticle',
#   '미세먼지/Noun',
#   '농도/Noun',
#   '2만/Number',
#   '이넘어가기도하넼/Foreign',
#   'ㅋㅋㅋㅋㅂㅋ/KoreanParticle'],
#  [],
#  ['왜/Noun',
#   '중국/Noun',
#   '생긴/Verb',
#   '미세먼지/Noun',
#   '때문/Noun',
#   '우리/Noun',
#   '공기청정기/Noun',
#   '사야하니/Verb',
#   '\xa0/Foreign',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋ/KoreanParticle',
#   '공기청정기/Noun',
#   '필요없다/Adjective',
#   '울/Noun',
#   '오빠/Noun',
#   '솔로/Noun',
#   '앨범/Noun',
#   '이면/Noun',
#   '공기/Noun',
#   '알아서/Verb',
#   '정화/Noun',
#   '한다/Verb',
#   'ㅜ/KoreanParticle',
#   '이/Determiner',
#   '거/Noun',
#   'ㅜ/KoreanParticle',
#   '머/Noun',
#   '첸/Noun',
#   '솔로/Noun',
#   '내/Noun',
#   '여긴/Verb',
#   '내/Noun',
#   '잇슬/Noun',
#   '곳/Noun',
#   '아니구나/Adjective',
#   '하고/Verb',
#   '자연스레/Adverb',
#   '이/Noun',
#   '나라/Noun',
#   '떠날/Verb',
#   '미세먼지/Noun',
#   '°̥̥̥̥̥̥̥̥◡͐°̥̥̥̥̥̥̥̥/Foreign',
#   '°̥̥̥̥̥̥̥̥◡͐°̥̥̥̥̥̥̥̥/Foreign',
#   '혈관/Noun',
#   '미세먼지/Noun',
#   '다/Adverb',
#   '씻겨가는/Verb',
#   '눈빛/Noun'],
#  ['강/Noun', '다니엘/Noun', '맑다/Adjective'],
#  ['강/Noun', '다니엘/Noun', '예쁘다/Adjective'],
#  ['강/Noun', '다니엘/Noun', '곱다/Adjective'],
#  ['강/Noun', '다니엘/Noun', '청정/Noun', '하다/Verb'],
#  ['강/Noun', '다니엘/Noun', '공기청정기/Noun'],
#  ['강/Noun', '다니엘/Noun', 'sf/Alpha', '94/Number'],
#  ['강/Noun', '다니엘/Noun', '피톤/Noun', '치드/Noun'],
#  ['강/Noun', '다니엘/Noun', '일/Modifier', '급수/Noun'],
#  ['#ForeverWithDaniel/Hashtag'],
#  ['#WeTrustDaniel/Hashtag'],
#  ['#BeYourselfDaniel/Hashtag',
#   '#hugforDanielpic/Hashtag',
#   '쉬바/Noun',
#   '다/Adverb',
#   '뛰어/Verb',
#   '나가서/Verb',
#   '마라톤/Noun',
#   '뛰어어어/Verb',
#   '인간/Noun',
#   '공기청정기/Noun',
#   '하라/Noun',
#   '오오오/Noun',
#   '노모/Noun',
#   '어/Suffix',
#   '미세먼지/Noun',
#   'ㅜㅠ/KoreanParticle',
#   '오늘/Noun',
#   '따라/Verb',
#   '미세먼지/Noun',
#   '분조/Noun',
#   '장이/Suffix',
#   '폭발/Noun',
#   '하는/Verb',
#   '이유/Noun',
#   '공기청정기/Noun',
#   '필터/Noun',
#   '사야/Verb',
#   '할/Verb',
#   '때/Noun',
#   '다가와서/Verb',
#   '병원/Noun',
#   '갔는데/Verb',
#   '원인/Noun',
#   '못잡고/Verb',
#   '대/Modifier',
#   '증/Noun',
#   '치료/Noun',
#   '열씨/Noun',
#   '미하/Noun',
#   '있는/Adjective',
#   '느낌/Noun',
#   '구/Noun',
#   '༼ಢ/Foreign',
#   'ಢ༽/Foreign',
#   '일간/Noun',
#   '경인/Noun',
#   '현장/Noun',
#   '취재/Noun',
#   '계속/Noun',
#   '되는/Verb',
#   '미세먼지/Noun',
#   '식당/Noun',
#   '울상/Noun',
#   '공기청정기/Noun',
#   '사업/Noun',
#   '활짝/Noun',
#   '\xa0/Foreign',
#   '마스크/Noun',
#   '황사/Noun',
#   '미세먼지/Noun',
#   '공기청정기/Noun',
#   '관련/Noun',
#   '주가/Noun',
#   '하락/Noun',
#   '출처/Noun',
#   '헤리티지/Noun',
#   '\xa0/Foreign',
#   '블로그/Noun',
#   '\xa0/Foreign',
#   '중국/Noun',
#   '온/Noun',
#   '중국/Noun',
#   '발/Noun',
#   '미세먼지/Noun',
#   '잡아주는/Verb',
#   '공기청정기/Noun',
#   '미세먼지/Noun'],
#  ['예산/Noun', '투입/Noun', '해야/Verb', '예/Modifier', '산이/Noun', '없으니/Adjective'],
#  ['안된다/Adjective',
#   '는/Verb',
#   '이해찬/Noun',
#   '문/Modifier',
#   '통/Noun',
#   '추경/Noun',
#   '예산/Noun'],
#  ['들먹이니/Verb', '잽싸게/Adjective', '맞장구/Noun', '치는/Verb', '꼴/Noun'],
#  ['허나/Verb', '중국/Noun', '계속/Noun', '날아오는/Verb', '먼지/Noun'],
#  ['무슨/Modifier',
#   '수로/Noun',
#   '막/Noun',
#   '건가/Noun',
#   '국제/Noun',
#   '적/Suffix',
#   '문제/Noun'],
#  ['풀/Noun', '않고/Verb', '돈/Noun', '처/Noun', '바르겠다는건/Verb', '혹/Noun'],
#  ['대한민국/Noun', '만/Suffix', '대형/Noun', '공기청정기/Noun'],
#  ['만든다는/Verb',
#   '건가/Noun',
#   '공기청정기/Noun',
#   '작년/Noun',
#   '삿/Noun',
#   '는데/Verb',
#   '그/Noun',
#   '때/Noun',
#   '틀/Noun',
#   '소리/Noun',
#   '날듯/Verb',
#   '말듯/Verb',
#   '해서/Verb',
#   '잘/Verb',
#   '안썻는데/Noun'],
#  ['어제/Noun',
#   '쓰자마자/Verb',
#   '우이/Noun',
#   '이/Suffix',
#   'ㅣ/KoreanParticle',
#   '이이이/Noun',
#   'ㅣㅇ/KoreanParticle',
#   '이이이/Noun',
#   'ㅣ/KoreanParticle',
#   '이잉이잉/Noun',
#   '완전/Noun',
#   '큰소리/Noun',
#   '낫/Noun',
#   '엇/VerbPrefix',
#   '는데/Verb'],
#  ['미세먼지/Noun',
#   '개객/Noun',
#   'ㄱ/KoreanParticle',
#   '기/Modifier',
#   '동한/Noun',
#   '이/Suffix',
#   '건강/Noun',
#   '해지니/Noun',
#   '미세먼지/Noun',
#   '사라졌어/Verb',
#   '인간/Noun',
#   '공기청정기/Noun',
#   '따로/Adverb',
#   '없구/Adjective',
#   '영덕군/Noun',
#   '미세먼지/Noun',
#   '로부터/Noun',
#   '우리/Noun',
#   '아이/Noun',
#   '지키기/Verb',
#   '어린이집/Noun',
#   '공기청정기/Noun',
#   '점검/Noun',
#   '\xa0/Foreign',
#   '환기/Noun',
#   '하려면/Verb',
#   '창문/Noun',
#   '열어야/Verb',
#   '하는데/Verb',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋ/KoreanParticle',
#   '열/Modifier',
#   '때/Noun',
#   '공기청정기/Noun',
#   '비명/Noun',
#   '질러서/Verb',
#   '무서워서/Adjective',
#   '닫아야/Verb',
#   '했어요/Verb',
#   '실제/Noun',
#   '일주일/Noun',
#   '미세먼지/Noun',
#   '경보/Noun',
#   '발령/Noun',
#   '기간/Noun',
#   '중/Noun',
#   '사흘/Noun',
#   '동안/Noun',
#   '외출/Noun',
#   '못/Noun',
#   '자/Noun',
#   '공기청정기/Noun',
#   '피스/Noun',
#   '넷/Noun',
#   '퓨어/Noun',
#   '360/Number',
#   '센서/Noun'],
#  ['소음/Noun',
#   '적고/Verb',
#   '오염/Noun',
#   '단계/Noun',
#   '따라/Verb',
#   'LED/Alpha',
#   '색상/Noun',
#   '달라지니까/Verb',
#   '편하네요/Adjective',
#   'H/Alpha',
#   '13/Number',
#   '등급/Noun',
#   '트루/Noun',
#   '헤파필터/Noun',
#   '사용/Noun',
#   '하/Suffix',
#   '집/Noun',
#   '안/Noun',
#   '미세먼지/Noun',
#   '걱정/Noun',
#   '안/Noun',
#   '푹/Noun',
#   '쉴/Verb',
#   '수/Noun',
#   '있어서/Adjective',
#   '너무/Adverb',
#   '좋아요/Adjective'],
#  ['#피스넷/Hashtag',
#   '#미세먼지/Hashtag',
#   '#공기청정기/Hashtag',
#   '#공기청정기추천/Hashtag',
#   '피스/Noun',
#   '넷/Noun',
#   '퓨어/Noun',
#   '360/Number',
#   '센/Foreign',
#   '야/Exclamation',
#   '오늘/Noun',
#   '미세먼지/Noun',
#   '보통/Noun',
#   '공기청정기/Noun',
#   '맨날/Adverb',
#   '빨간/Adjective',
#   '불이다가/Verb',
#   '지금/Noun',
#   '파란/Noun',
#   '불/Noun',
#   '환기/Noun',
#   '할/Verb',
#   '타이밍/Noun',
#   '롸잇/Noun',
#   '나우/Noun',
#   '네/Determiner',
#   '매스/Noun',
#   '미디어/Noun',
#   '들/Suffix',
#   '미세먼지/Noun',
#   '공포/Noun',
#   '조장/Noun',
#   '뉴스/Noun',
#   '끝나자마자/Verb',
#   '공기청정기/Noun',
#   '광고/Noun',
#   '때리고/Verb',
#   '공생/Noun',
#   '공사/Noun',
#   '우리/Noun',
#   '남이가지/Verb',
#   '\xa0/Foreign',
#   '나락/Noun',
#   '떨어진/Verb',
#   '피부/Noun',
#   '상태/Noun',
#   '며칠/Noun',
#   '째/Suffix',
#   '조/Modifier',
#   '아지/Noun',
#   '않는다/Verb',
#   '정부/Noun',
#   '미세먼지/Noun',
#   '막을수/Verb',
#   '없다면/Adjective',
#   '공기청정기/Noun',
#   '마스크/Noun',
#   '모/Modifier',
#   '공/Modifier',
#   '클렌/Noun',
#   '징/Noun',
#   '용품/Noun',
#   '지원/Noun',
#   '하라/Noun',
#   '미세먼지/Noun',
#   '근/Modifier',
#   '원지/Noun',
#   '만든/Verb',
#   '미세먼지/Noun',
#   '제거/Noun',
#   '용/Noun',
#   '공기청정기/Noun',
#   '구매/Noun',
#   '완료/Noun',
#   '공기청정기/Noun',
#   '#미세먼지/Hashtag',
#   '#천식/Hashtag',
#   '#아토피/Hashtag',
#   '#비염/Hashtag',
#   '#폐질환/Hashtag',
#   '#기관지/Hashtag',
#   '#진드기/Hashtag',
#   '#황사/Hashtag',
#   '#냄새/Hashtag',
#   '#음식냄새/Hashtag',
#   '#태아/Hashtag',
#   '#애완동물비듬/Hashtag'],
#  ['유해/Noun',
#   '물질/Noun',
#   '99.97%/Number',
#   '정화/Noun',
#   '하는/Verb',
#   '놀라운/Adjective',
#   '성능/Noun'],
#  [],
#  ['집안/Noun',
#   '사용/Noun',
#   '되는/Verb',
#   '공기청정기/Noun',
#   '성능/Noun',
#   '제작사/Noun',
#   '요청/Noun',
#   '해서/Verb',
#   '눈/Noun'],
#  ['확인/Noun',
#   '하/Exclamation',
#   '심/Noun',
#   '가족/Noun',
#   '건강/Noun',
#   '지킬수/Verb',
#   '있습니다/Adjective'],
#  [],
#  ['\xa0/Foreign',
#   '공기청정기/Noun',
#   '필요한가요/Adjective',
#   '집안/Noun',
#   '공기/Noun',
#   '정화/Noun',
#   '하는게/Verb',
#   '의미/Noun',
#   '있을까/Adjective',
#   '싶어서요/Verb',
#   '사람/Noun',
#   '집안/Noun',
#   '살/Noun',
#   '수/Noun',
#   '있는게/Adjective',
#   '아닌데/Adjective',
#   '나가면/Verb',
#   '어찌/Noun',
#   '피/Noun',
#   '미세먼지/Noun',
#   '그대로/Noun',
#   '마시는데/Verb',
#   '—/Foreign',
#   '몰라/Verb',
#   '효/Noun',
#   '전/Noun',
#   '업서요/Verb',
#   '안/VerbPrefix',
#   '써요/Verb',
#   '\xa0/Foreign',
#   '미세먼지/Noun',
#   '잡겠다고/Verb',
#   '건물/Noun',
#   '옥상/Noun',
#   '시내/Noun',
#   '곳곳/Noun',
#   '공기청정기/Noun',
#   '설치/Noun',
#   '하겠다는/Verb',
#   '문재인/Noun',
#   '정부/Noun',
#   '차라리/Noun',
#   '온/Noun',
#   '하늘/Noun',
#   '비닐/Noun',
#   '덮지/Verb',
#   '그래요/Adjective',
#   '아무리/Adverb',
#   '똥/Noun',
#   '대가리/Noun',
#   '정권/Noun',
#   '해도/Noun',
#   '공기청정기/Noun',
#   '미세먼지/Noun',
#   '잡겠다는/Verb',
#   '발상/Noun',
#   '어떻게/Adjective',
#   '할/Verb',
#   '수/Noun',
#   '있는지/Adjective',
#   '황당함을/Adjective',
#   '넘어/Verb',
#   '황망/Noun',
#   '그/Noun',
#   '자체/Noun',
#   '네/Suffix',
#   '사기꾼/Noun',
#   '이명박/Noun',
#   '로봇/Noun',
#   '물고기/Noun',
#   '개/Noun',
#   '웃겨요/Verb',
#   '제/Modifier',
#   '건/Noun',
#   '공기청정기/Noun',
#   '능이/Noun',
#   '탈취/Noun',
#   '기능/Noun',
#   '있어요/Adjective',
#   '\xa0/Foreign'],
#  ['스마트폰/Noun',
#   '제어/Noun',
#   '되고/Verb',
#   '미세먼지/Noun',
#   '수치/Noun',
#   '표시/Noun',
#   '해주는건/Verb',
#   '비싸더라구요/Adjective',
#   '엘지/Noun',
#   '저렴하지만/Adjective',
#   '구매/Noun',
#   '하실/Verb',
#   '때/Noun',
#   '최저/Noun',
#   '가바/Noun',
#   '보지/Noun',
#   '마시고/Verb',
#   '위메프/Noun',
#   '쿠팡/Noun',
#   '같은데서/Adjective',
#   '이벤트/Noun',
#   '해서/Verb',
#   '더/Noun',
#   '저렴할수도/Adjective',
#   '있어요/Adjective',
#   '체크/Noun',
#   '같이/Adverb',
#   '해보세요/Verb',
#   'ㅇ/KoreanParticle',
#   '멀쩡한/Adjective',
#   '4/Number',
#   '대강/Noun',
#   '부수는데/Adjective',
#   '수천/Modifier',
#   '억원/Noun',
#   '낭비하면서/Adjective',
#   '미세먼지/Noun',
#   '더/Noun',
#   '날리지말고/Verb',
#   '전기요금/Noun',
#   '보테라/Verb',
#   '24시간/Number',
#   '일주일/Noun',
#   '내내/Noun',
#   '튼/Verb',
#   '공기청정기/Noun',
#   '전기요금/Noun',
#   '얼마/Noun',
#   '\xa0/Foreign',
#   '난/Noun',
#   '진짜/Noun',
#   '내/Noun',
#   '정국/Noun',
#   '이형/Noun',
#   '이/Noun',
#   '여섯/Determiner',
#   '글자/Noun',
#   '죽을꺼라고는/Verb',
#   '생각/Noun',
#   '안/VerbPrefix',
#   '해봤다고/Verb',
#   '정국/Noun',
#   '이/Suffix',
#   '형/Noun',
#   '형/Noun',
#   '왜/Noun',
#   '형/Noun',
#   '귀엽고/Adjective',
#   '난리/Noun',
#   '고/Modifier',
#   '오오오/Noun',
#   'ㅠㅠㅠㅠ/KoreanParticle',
#   '미세먼지/Noun',
#   '견디게/Verb',
#   '하는/Verb',
#   '쩡꾸/Noun',
#   '이/Noun',
#   '피톤/Noun',
#   '치드/Noun',
#   '같은/Adjective',
#   '꾸꾸/Adverb',
#   '공기청정기/Noun',
#   '같은/Adjective',
#   '꾸꾸/Adverb',
#   'BTS/Alpha',
#   '재난/Noun',
#   '수준/Noun',
#   '미세먼지/Noun',
#   '공습/Noun',
#   '놀란/Noun',
#   '분/Noun',
#   '들/Suffix',
#   '많았던/Adjective',
#   '탓/Noun',
#   '공기청정기/Noun',
#   '수요/Noun',
#   '급증/Noun',
#   '있습니다/Adjective'],
#  ['당장/Noun',
#   '주문/Noun',
#   '하더라도/Verb',
#   '대기/Noun',
#   '기간/Noun',
#   '있을/Adjective',
#   '정도/Noun',
#   '요/Noun'],
#  ['\xa0/Foreign',
#   '이번/Noun',
#   '미세먼지/Noun',
#   '하도/Verb',
#   '고생/Noun',
#   '해서/Verb',
#   '공기청정기/Noun',
#   '알아봄/Verb',
#   '대부분/Noun',
#   '중국/Noun',
#   '만듦/Verb',
#   '중국/Noun',
#   '발/Noun',
#   '미세먼지/Noun',
#   '중국/Noun',
#   '만든/Verb',
#   '공기청정기/Noun',
#   '걸러/Verb',
#   '안함/Noun',
#   '뤼얼리/Noun',
#   '둘/Noun',
#   '다/Adverb',
#   '정신/Noun',
#   '이상자/Noun',
#   '들/Suffix'],
#  [],
#  ['딱/Adverb',
#   '영화/Noun',
#   '본/Verb',
#   '후/Noun',
#   '멀쩡한/Adjective',
#   '청정/Noun',
#   '발전/Noun',
#   '원자력/Noun',
#   '발전소/Noun',
#   '폐쇄/Noun',
#   '탈/Noun',
#   '원전/Noun',
#   '하겠다는/Verb',
#   '자/Noun'],
#  [],
#  ['중국/Noun',
#   '말/Noun',
#   '한마디/Noun',
#   '못/Noun',
#   '공기청정기/Noun',
#   '미세먼지/Noun',
#   '덮혀있는/Verb',
#   '전/Modifier',
#   '국토/Noun',
#   '정화/Noun',
#   '시키겠다는/Verb',
#   '자/Noun'],
#  [],
#  ['애송이/Noun',
#   '북한주민/Noun',
#   '들/Suffix',
#   '기/Noun',
#   '망하는/Adjective',
#   '것/Noun',
#   '남한/Noun',
#   '국민/Noun',
#   '들/Suffix',
#   '매일/Noun',
#   '구라/Noun',
#   '질/Noun',
#   '기/Noun',
#   '망하는/Adjective',
#   '자/Noun',
#   '똑같은/Adjective',
#   '인간/Noun',
#   '들/Suffix',
#   '코웨이/Noun',
#   '미세먼지/Noun',
#   '대비/Noun',
#   '공기청정기/Noun',
#   '특별/Noun',
#   '행사/Noun',
#   '진행/Noun',
#   '\xa0/Foreign',
#   '미세먼지/Noun',
#   '기술/Noun',
#   '적/Suffix',
#   '해법/Noun',
#   '있나/Adjective',
#   '좀/Noun',
#   '검색/Noun',
#   '해보니까/Verb',
#   '나오는/Verb',
#   '게/Noun',
#   '2/Number',
#   '가지/Noun',
#   '하나/Noun',
#   '습성/Noun',
#   '침착/Noun',
#   '이용/Noun',
#   '하여/Verb',
#   '분무/Noun',
#   '살수/Noun',
#   '하여/Verb',
#   '미세먼지/Noun',
#   '제거/Noun',
#   '하는/Verb',
#   '방식/Noun',
#   '60/Number',
#   'm/Alpha',
#   '높이/Noun',
#   '초대형/Noun',
#   '공기청정기/Noun',
#   '설치/Noun',
#   '하는/Verb',
#   '방식/Noun',
#   '그런데/Conjunction',
#   '검색/Noun',
#   '해보니/Verb',
#   '광고/Noun',
#   '비해/Verb',
#   '효과/Noun',
#   '미비한/Adjective',
#   '편인듯/Verb',
#   '공기청정기/Noun',
#   '필터/Noun',
#   '어떻게/Adjective',
#   '버려야/Verb',
#   '할까/Verb',
#   '요/Noun',
#   '#미세먼지/Hashtag',
#   '#공기청정기/Hashtag',
#   '혁재/Noun',
#   '오늘/Noun',
#   '뭐/Noun',
#   '해/Verb',
#   '콘서트/Noun',
#   '한/Determiner',
#   '달/Noun',
#   '남짓/Noun',
#   '남지/Noun',
#   '않았지만/Verb',
#   '그래도/Adverb',
#   '한/Verb',
#   '동안/Noun',
#   '네/Noun',
#   '일상/Noun',
#   '소식/Noun',
#   '들을/Verb',
#   '길이/Noun',
#   '없을/Adjective',
#   '것/Noun',
#   '같아/Adjective',
#   '아쉬워/Adjective',
#   'ㅠ/KoreanParticle',
#   'ㅠ/KoreanParticle',
#   '요즘/Noun',
#   '미세먼지/Noun',
#   '많지만/Adjective',
#   '햇살/Noun',
#   '좋아/Adjective',
#   '공기청정기/Noun',
#   '잘/Verb',
#   '돌아가는/Verb',
#   '통/Noun',
#   '유리/Noun',
#   '벽면/Noun',
#   '음식점/Noun',
#   '맛있는/Adjective',
#   '거/Noun',
#   '먹으면서/Verb',
#   '햇빛/Noun',
#   '좀/Noun',
#   '쬐고/Verb',
#   '그랬으면/Adjective',
#   '좋겠당/Adjective',
#   '[#김서형/Hashtag'],
#  ['미세먼지/Noun', '날려주는/Verb'],
#  ['인간/Noun', '공기청정기/Noun'],
#  ['왔서/Verb',
#   '형/Noun',
#   '출처/Noun',
#   '플라이/Noun',
#   '업/Noun',
#   '엔터테인먼트/Noun',
#   '네이버/Noun',
#   '포스트/Noun',
#   '값싼/Verb',
#   '산업/Noun',
#   '용/Noun',
#   '전기/Noun',
#   '용광로/Noun',
#   '돌리고/Verb'],
#  ['오염/Noun', '물질/Noun', '무단/Noun', '배출/Noun', '누구/Noun', '죽이려/Verb', '구/Noun'],
#  [],
#  ['#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '열/Modifier',
#   '외가/Noun',
#   '많아/Adjective',
#   '효과/Noun',
#   '없다/Adjective',
#   '전면/Noun',
#   '2/Number',
#   '부제/Noun',
#   '실시/Noun',
#   '해야/Verb'],
#  [],
#  ['#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '…#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '…#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '…#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '관료/Noun',
#   '천국/Noun',
#   '국민/Noun',
#   '지옥/Noun'],
#  [],
#  ['#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '…#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '…#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '…#스모그/Hashtag',
#   '#공해/Hashtag',
#   '#매연/Hashtag',
#   '#마스크/Hashtag',
#   '#SUV/Hashtag',
#   '#노후차/Hashtag',
#   '#미세먼지/Hashtag',
#   '#배출가스/Hashtag',
#   '#자연보호/Hashtag',
#   '#대기오염/Hashtag',
#   '#환경오염/Hashtag',
#   '#발암물질/Hashtag',
#   '#유해물질/Hashtag',
#   '#역학조사/Hashtag',
#   '#공기청정기/Hashtag',
#   '#집단소송제/Hashtag',
#   '징벌/Noun',
#   '적/Suffix',
#   '손해배상/Foreign',
#   '\xa0/Foreign',
#   '공기/Noun',
#   '정화/Noun',
#   '장치/Noun',
#   '없는/Adjective',
#   '교실/Noun',
#   '미세먼지/Noun',
#   '로부터/Noun',
#   '안전하려면/Adjective',
#   '#미세먼지/Hashtag',
#   '#세계잉여금_정산/Hashtag',
#   '#공기청정기/Hashtag',
#   '#공기정화장치/Hashtag',
#   '#기계환기설비/Hashtag',
#   '\xa0/Foreign',
#   '송/Noun',
#   '경원/Noun',
#   '기자/Noun',
#   '미세먼지/Noun',
#   '심해서/Adjective',
#   '어제/Noun',
#   '공기청정기/Noun',
#   '하나/Noun',
#   '구매/Noun',
#   '했습니다/Verb'],
#  ['어제/Noun',
#   '처음/Noun',
#   '써/Verb',
#   '봤는데/Verb',
#   '잘/Verb',
#   '가동/Noun',
#   '되고/Verb',
#   '좋네요/Adjective',
#   '한국/Noun',
#   '중국/Noun',
#   '공동/Noun',
#   '공기청정기/Noun',
#   '투자/Noun',
#   '할/Verb',
#   '돈/Noun',
#   '미세먼지/Noun',
#   '주/Modifier',
#   '범인/Noun',
#   '공장/Noun',
#   '굴뚝/Noun',
#   '엄청난/Adjective',
#   '돈/Noun',
#   '투자/Noun',
#   '하여야/Verb',
#   '함/Noun',
#   '미세먼지/Noun',
#   '때문/Noun',
#   '이민/Noun',
#   '가고/Verb',
#   '싶다/Verb',
#   '생각/Noun',
#   '한적/Noun',
#   '또/Noun',
#   '처음/Noun',
#   '공기청정기/Noun',
#   '사자/Noun',
#   '그럼/Adjective',
#   '기/Modifier',
#   '헤기/Noun',
#   '들/Suffix',
#   '자유당/Noun',
#   '대책/Noun',
#   '내놔라/Verb'],
#  ['언제/Noun', '학교/Noun', '공기청정기/Noun', '없다고난/Adjective', '리더/Noun'],
#  ['미세먼지/Noun',
#   '대책/Noun',
#   '단기간/Noun',
#   '미세먼지/Noun',
#   '사라지나/Verb',
#   '박근혜/Noun',
#   '때/Noun',
#   '고등어/Noun',
#   '쉴드치던/Verb',
#   '씨방/Noun',
#   '새/Modifier',
#   '미세먼지/Noun',
#   '걱정/Noun',
#   '이/Determiner',
#   '제/Modifier',
#   '그만/Modifier'],
#  ['큐텐/Noun', '미세먼지/Noun', '끝내세요/Verb'],
#  ['\xa0/Foreign'],
#  ['#미세먼지/Hashtag',
#   '#공기청정기/Hashtag',
#   '#샤오미에어/Hashtag',
#   '#직구/Hashtag',
#   '#사오미중국발미세먼지가/Hashtag',
#   '한반도/Noun',
#   '뒤/Noun',
#   '덮어도/Verb',
#   '하는것은/Verb',
#   '공기청정기/Noun',
#   '구입/Noun',
#   '너무나/Adverb',
#   '황당하다/Adjective'],
#  ['국민/Noun',
#   '들/Suffix',
#   '미세먼지/Noun',
#   '독성/Noun',
#   '먼지/Noun',
#   '긴급/Noun',
#   '대책/Noun',
#   'ㅂ/KoreanParticle',
#   '바/Noun',
#   '반/Modifier',
#   '진/Noun',
#   '마스크/Noun',
#   '지급/Noun',
#   '하시요/Verb',
#   '세종/Noun',
#   '특별자치시/Noun',
#   '고/Modifier',
#   '농도/Noun',
#   '미세먼지/Noun',
#   '인한/Adjective',
#   '주민/Noun',
#   '건강/Noun',
#   '피해/Noun',
#   '최소/Noun',
#   '화하기/Adjective',
#   '위해/Noun',
#   '초등학교/Noun',
#   '주변/Noun',
#   '살수/Noun',
#   '및/Noun',
#   '공기청정기/Noun',
#   '마스크/Noun',
#   '보급/Noun',
#   '등/Noun',
#   '비상/Noun',
#   '저/Determiner',
#   '감/Noun',
#   '조치/Noun',
#   '강화/Noun',
#   '시행/Noun',
#   '합니다/Verb'],
#  ['\xa0/Foreign', '내일/Noun', '미세먼지/Noun'],
#  ['집/Noun', '밖/Noun', '차단/Noun', '답/Noun'],
#  ['내/Noun', '마시는/Verb', '공기/Noun', '내/Noun', '지킨다/Verb'],
#  ['\xa0/Foreign'],
#  ['#바보사랑/Hashtag',
#   '#babosarang/Hashtag',
#   '#데일리/Hashtag',
#   '#daily/Hashtag',
#   '#korea/Hashtag',
#   '#seoul/Hashtag',
#   '#미세먼지/Hashtag',
#   '#공기청정기/Hashtag',
#   '#미세먼지측정기/Hashtag',
#   '#공기청정기추천/Hashtag',
#   '#소형공기청정기/Hashtag',
#   '원룸공기청정/Foreign']]

# %% [markdown]
# ## Train

# %%
from gensim.models import Word2Vec, fasttext

# %%
# window size=2, 핵심단어 주변 2개 추출, 2차원으로 표시
Skip_Gram_model = Word2Vec(corpus, size=2, window=2, min_count=2, workers=2, iter=1000, sg=1)

# %%
words = Skip_Gram_model.wv.index2word
words
# Out:
# ['미세먼지/Noun',
#  '공기청정기/Noun',
#  '\xa0/Foreign',
#  '#공기청정기/Hashtag',
#  '들/Suffix',
#  '#미세먼지/Hashtag',
#  '마스크/Noun',
#  '적/Suffix',
#  '하는/Verb',
#  '#공해/Hashtag',
#  '#매연/Hashtag',
#  '#마스크/Hashtag',
#  '#SUV/Hashtag',
#  '#노후차/Hashtag',
#  '#배출가스/Hashtag',
#  '#자연보호/Hashtag',
#  '#대기오염/Hashtag',
#  '#환경오염/Hashtag',
#  '#발암물질/Hashtag',
#  '#유해물질/Hashtag',
#  '#역학조사/Hashtag',
#  '#집단소송제/Hashtag',
#  '징벌/Noun',
#  '손해배상/Foreign',
#  '중국/Noun',
#  '우리/Noun',
#  '집/Noun',
#  '나/Noun',
#  '이/Noun',
#  '안/Noun',
#  '공기/Noun',
#  '다/Adverb',
#  '거/Noun',
#  '강/Noun',
#  '진짜/Noun',
#  '인간/Noun',
#  '사람/Noun',
#  '설치/Noun',
#  '학교/Noun',
#  '대책/Noun',
#  '내/Noun',
#  '때/Noun',
#  '보급/Noun',
#  '다니엘/Noun',
#  '뉴스/Noun',
#  '것/Noun',
#  '너무/Adverb',
#  '…#스모그/Hashtag',
#  '오늘/Noun',
#  '저/Determiner',
#  '정화/Noun',
#  '하나/Noun',
#  '같은/Adjective',
#  '해서/Verb',
#  '안/VerbPrefix',
#  '좀/Noun',
#  '많이/Adverb',
#  '건강/Noun',
#  '돈/Noun',
#  '국민/Noun',
#  '더/Noun',
#  '요즘/Noun',
#  'ㅠㅠ/KoreanParticle',
#  '말/Noun',
#  '#스모그/Hashtag',
#  '정부/Noun',
#  '하/Suffix',
#  '할/Verb',
#  '이/Determiner',
#  '교실/Noun',
#  '구매/Noun',
#  '운영/Noun',
#  '반/Noun',
#  '1/Number',
#  '잘/Verb',
#  '전/Noun',
#  '제/Noun',
#  '게/Noun',
#  '없는/Adjective',
#  '그래도/Adverb',
#  '보고/Noun',
#  '수/Noun',
#  '살/Noun',
#  '어제/Noun',
#  '이산화탄소/Noun',
#  '이/Suffix',
#  'ㅠ/KoreanParticle',
#  '생각/Noun',
#  '한/Determiner',
#  '집안/Noun',
#  '필터/Noun',
#  '감/Noun',
#  '한국/Noun',
#  '돼/Verb',
#  '”/Foreign',
#  '출처/Noun',
#  '건가/Noun',
#  '이번/Noun',
#  '시간/Noun',
#  '낫/Noun',
#  '때문/Noun',
#  '하면/Verb',
#  '죽을래/Verb',
#  '흡입/Noun',
#  '‘/Foreign',
#  '군/Suffix',
#  '걱정/Noun',
#  '등/Noun',
#  '대/Verb',
#  '한/Verb',
#  '피스/Noun',
#  '넷/Noun',
#  '단계/Noun',
#  '계속/Noun',
#  '있는/Adjective',
#  '수치/Noun',
#  '왜/Noun',
#  '만든/Verb',
#  '로부터/Noun',
#  '2/Number',
#  '4/Number',
#  '먼지/Noun',
#  '자/Noun',
#  '형/Noun',
#  '초등학교/Noun',
#  '중/Noun',
#  '“/Foreign',
#  '네이버/Noun',
#  '가장/Noun',
#  '요/Noun',
#  '그/Noun',
#  'ㅋㅋㅋㅋㅋ/KoreanParticle',
#  '정도/Noun',
#  '있어/Adjective',
#  '해/Noun',
#  '속/Noun',
#  '아까/Adjective',
#  '하기/Verb',
#  '제거/Noun',
#  '용/Noun',
#  '난/Noun',
#  '광고/Noun',
#  '공/Modifier',
#  '못/Noun',
#  '제/Modifier',
#  '함/Noun',
#  '일주일/Noun',
#  '엿/Modifier',
#  '청정/Noun',
#  '되는/Verb',
#  '난리/Noun',
#  '틀/Noun',
#  '창문/Noun',
#  '환기/Noun',
#  '위해/Noun',
#  '하여/Verb',
#  '야/Exclamation',
#  '심해서/Adjective',
#  '해야/Verb',
#  '있을까/Adjective',
#  '했습니다/Verb',
#  '뭐/Noun',
#  '온/Noun',
#  '봄철/Noun',
#  '추진/Noun',
#  '살수차/Noun',
#  'ㆍ/Foreign',
#  '분진/Noun',
#  '차량/Noun',
#  '확대/Noun',
#  '경로당/Noun',
#  '590/Number',
#  '지역/Noun',
#  '동/Modifier',
#  '세터/Noun',
#  '18만/Number',
#  '매/Foreign',
#  '#더부천/Hashtag',
#  '시작/Noun',
#  '퓨어/Noun',
#  '360/Number',
#  '곳/Noun',
#  '하지/Verb',
#  '했는데/Verb',
#  '효과/Noun',
#  '농도/Noun',
#  '기/Modifier',
#  'ㅡ/KoreanParticle',
#  '3/Number',
#  '기/Noun',
#  '쌤/Noun',
#  '있습니다/Adjective',
#  '탓/Noun',
#  '기간/Noun',
#  'ㅋㅋㅋ/KoreanParticle',
#  'ㅋㅋ/KoreanParticle',
#  '탈/Noun',
#  '잘/VerbPrefix',
#  '아님/Adjective',
#  '아니/Adjective',
#  '죽게/Verb',
#  '제발/Noun',
#  '시/Modifier',
#  '아직도/Adverb',
#  '먹구/Verb',
#  '바로/Noun',
#  '얼굴/Noun',
#  '사야/Verb',
#  '한다/Verb',
#  '필수/Noun',
#  '혈관/Noun',
#  '넘/Verb',
#  '입니다/Adjective',
#  '주/Noun',
#  '성/Suffix',
#  '분/Noun',
#  '황사/Noun',
#  '일/Noun',
#  '하세요/Verb',
#  '보니/Verb',
#  '옥상/Noun',
#  '보면/Verb',
#  '대가리/Noun',
#  '않는다/Verb',
#  '모든/Noun',
#  '사십/Modifier',
#  '쇼/Noun',
#  '회사/Noun',
#  '건물/Noun',
#  '잔뜩/Noun',
#  '눈/Noun',
#  '감기/Noun',
#  '달/Noun',
#  '애기/Noun',
#  '다행/Noun',
#  '스모그/Noun',
#  '이건/Noun',
#  '울/Modifier',
#  '그런데/Conjunction',
#  '거리/Noun',
#  '대형/Noun',
#  '있나/Adjective',
#  '대/Modifier',
#  '니아/Noun',
#  '수요/Noun',
#  '영상/Noun',
#  '개/Noun',
#  '웃음/Noun',
#  '완전/Noun',
#  '몸/Noun',
#  '가습기/Noun',
#  '에어컨/Noun',
#  '삶/Noun',
#  '몰라/Verb',
#  '조장/Noun',
#  '아주/Noun',
#  '않을까/Verb',
#  '필요없다/Adjective',
#  '알/Noun',
#  '로/Noun',
#  '네/Suffix',
#  '역할/Noun',
#  '울/Noun',
#  '잉/Noun',
#  '문제/Noun',
#  '건/Noun',
#  '와/Verb',
#  '사립/Noun',
#  '실내/Noun',
#  '시발/Noun',
#  '민윥기/Noun',
#  '나라/Noun',
#  '느낌/Noun',
#  '사실/Noun',
#  '최근/Noun',
#  '하는데/Verb',
#  '외/Noun',
#  '일부/Noun',
#  '수준/Noun',
#  '수명/Noun',
#  '사서/Noun',
#  '두/Determiner',
#  '정말/Noun',
#  '필요한가요/Adjective',
#  '하는게/Verb',
#  '의미/Noun',
#  '싶어서요/Verb',
#  '있는게/Adjective',
#  '아닌데/Adjective',
#  '나가면/Verb',
#  '어찌/Noun',
#  '피/Noun',
#  '그대로/Noun',
#  '마시는데/Verb',
#  '—/Foreign',
#  '머/Noun',
#  '하늘/Noun',
#  '맛있는/Adjective',
#  '있는지/Adjective',
#  '먹고/Verb',
#  '탐정/Noun',
#  '위/Noun',
#  '이제/Noun',
#  '나와서/Verb',
#  '도착/Noun',
#  '없구/Adjective',
#  '늦게/Verb',
#  '그냥/Noun',
#  '못/VerbPrefix',
#  '#thebucheon부천시/Hashtag',
#  '네/Noun',
#  '나가서/Verb',
#  '약/Noun',
#  '심하다고/Adjective',
#  '이렇게/Adverb',
#  '고민/Noun',
#  '기분/Noun',
#  '대비/Noun',
#  '소음/Noun',
#  '네/Determiner',
#  '얼마/Noun',
#  '최악/Noun',
#  '만/Suffix',
#  '경보/Noun',
#  '발령/Noun',
#  '알아서/Verb',
#  '를/Noun',
#  '질/Noun',
#  '측정/Noun',
#  '봤는데/Verb',
#  '학생/Noun',
#  '그럼/Adjective',
#  '탐라/Noun',
#  '국방부/Noun',
#  '장병/Noun',
#  '보호/Noun',
#  '병영/Noun',
#  '생활관/Noun',
#  '최저/Noun',
#  '공동/Noun',
#  '하/Exclamation',
#  '5/Number',
#  '주변/Noun',
#  '언론/Noun',
#  '삼성/Noun',
#  '해도/Noun',
#  '있다/Adjective',
#  '하게/Verb',
#  '아이/Noun',
#  '코/Noun',
#  '지옥/Noun',
#  '24시간/Number',
#  '풀/Noun',
#  '가동/Noun',
#  '전기/Noun',
#  '써/Verb',
#  '딱/Adverb',
#  '째/Suffix',
#  '마시는/Verb',
#  '대중교통/Noun',
#  '이용/Noun',
#  '소리/Noun',
#  '문/Noun',
#  '中國/Foreign',
#  '규제/Noun',
#  '공장/Noun',
#  '공포/Noun',
#  '조/Modifier',
#  '오빠/Noun',
#  'ㅠㅠㅠㅠ/KoreanParticle',
#  '걸러/Verb',
#  '는/Verb',
#  '행사/Noun',
#  '있어서/Adjective',
#  '무슨/Modifier',
#  '누구/Noun',
#  '솔로/Noun',
#  'ㅜ/KoreanParticle',
#  '°̥̥̥̥̥̥̥̥◡͐°̥̥̥̥̥̥̥̥/Foreign',
#  '피톤/Noun',
#  '치드/Noun',
#  '하라/Noun',
#  '오오오/Noun',
#  '따라/Verb',
#  '구/Noun',
#  '발/Noun',
#  '예산/Noun',
#  '통/Noun',
#  '는데/Verb',
#  'ㅣ/KoreanParticle',
#  '이이이/Noun',
#  '열/Modifier',
#  '동안/Noun',
#  '오염/Noun',
#  '사용/Noun',
#  '#공기청정기추천/Hashtag',
#  '물질/Noun',
#  '성능/Noun',
#  '하겠다는/Verb',
#  '어떻게/Adjective',
#  '있어요/Adjective',
#  '되고/Verb',
#  '멀쩡한/Adjective',
#  '전기요금/Noun',
#  '정국/Noun',
#  '고/Modifier',
#  '꾸꾸/Adverb',
#  '망하는/Adjective',
#  '검색/Noun',
#  '살수/Noun',
#  '방식/Noun',
#  '처음/Noun',
#  '투자/Noun']

# %%
vectors = Skip_Gram_model.wv.vectors
#각 단어들의 vector가 나온다.
vectors
# Out:
# array([[-6.56310976e-01, -7.73581326e-01],
#        [-6.45916045e-01, -9.67985630e-01],
#        [-8.52591991e-01,  9.33994800e-02],
#        [-2.17525363e+00,  7.44337499e-01],
#        [-7.27316976e-01, -9.24321353e-01],
#        [-3.13694811e+00,  1.11348963e+00],
#        [-7.43837118e-01, -2.22445816e-01],
#        [-1.97911024e+00,  6.45671070e-01],
#        [-7.51774192e-01, -1.04024899e+00],
#        [-4.80492878e+00,  1.73878479e+00],
#        [-5.13286018e+00,  1.84708130e+00],
#        [-5.45040464e+00,  1.96610725e+00],
#        [-5.55382156e+00,  2.00952315e+00],
#        [-5.55826283e+00,  2.01196074e+00],
#        [-5.82359648e+00,  2.09206724e+00],
#        [-5.89145470e+00,  2.12509704e+00],
#        [-5.74302912e+00,  2.06240773e+00],
#        [-5.65077448e+00,  2.02359962e+00],
#        [-5.28556013e+00,  1.90091372e+00],
#        [-4.95662785e+00,  1.78472781e+00],
#        [-4.53346539e+00,  1.62839651e+00],
#        [-3.71885562e+00,  1.33731461e+00],
#        [-3.34834909e+00,  1.17672086e+00],
#        [-2.74940133e+00,  9.58123624e-01],
#        [-7.10090578e-01, -1.56354213e+00],
#        [-6.70532584e-01, -1.13606048e+00],
#        [-8.01514387e-01, -2.04195166e+00],
#        [-8.28021288e-01, -2.20853543e+00],
#        [-7.44253874e-01, -6.65429115e-01],
#        [-9.43959355e-01, -2.82821846e+00],
#        [-1.24783373e+00,  1.37134448e-01],
#        [-7.60450542e-01, -2.07682776e+00],
#        [-7.84442365e-01, -1.14947629e+00],
#        [-1.17534113e+00, -4.60571098e+00],
#        [-7.85000265e-01, -3.98701549e-01],
#        [-7.13429689e-01, -1.01196432e+00],
#        [-7.89099634e-01, -6.31017923e-01],
#        [-7.61557698e-01, -1.61851764e+00],
#        [-7.60234296e-01, -1.93872881e+00],
#        [-1.10046661e+00,  6.82397038e-02],
#        [-8.76946986e-01, -4.73710984e-01],
#        [-7.64451504e-01, -1.73712385e+00],
#        [-1.23832202e+00,  1.13808744e-01],
#        [-1.27324200e+00, -4.97960424e+00],
#        [-7.63376594e-01, -7.22068071e-01],
#        [-7.69980609e-01, -1.12510800e+00],
#        [-7.96200156e-01, -1.76111245e+00],
#        [-3.88787222e+00,  1.38297033e+00],
#        [-8.59809875e-01, -3.01141173e-01],
#        [-1.07588542e+00, -5.10291271e-02],
#        [-9.17061985e-01, -1.47106439e-01],
#        [-8.82442653e-01, -2.49868870e+00],
#        [-9.37081575e-01, -3.04868054e+00],
#        [-8.36817801e-01, -2.36672568e+00],
#        [-8.75657201e-01, -4.26022410e-01],
#        [-7.11846590e-01, -8.13326955e-01],
#        [-7.77155817e-01, -2.07605171e+00],
#        [-9.29396152e-01, -2.00897500e-01],
#        [-1.02577484e+00, -3.45094204e+00],
#        [-8.58357012e-01, -3.17061655e-02],
#        [-1.00039625e+00, -3.32466483e+00],
#        [-9.15077865e-01, -2.77307343e+00],
#        [-7.59986997e-01, -1.83785927e+00],
#        [-6.90361440e-01, -1.91675499e-01],
#        [-5.05360508e+00,  1.83381712e+00],
#        [-7.28514254e-01, -1.35444963e+00],
#        [-7.49386370e-01, -1.69725561e+00],
#        [-7.40080416e-01, -1.70039308e+00],
#        [-7.20906913e-01, -1.10926092e+00],
#        [-8.75633597e-01, -2.96703458e-01],
#        [-1.07612562e+00, -3.39628434e+00],
#        [-9.82845497e+00,  3.26500440e+00],
#        [-7.61232018e-01, -1.89416361e+00],
#        [-1.13016140e+00, -3.78303313e+00],
#        [-9.38394248e-01, -2.73350787e+00],
#        [-6.97514951e-01, -1.04701543e+00],
#        [-1.26337278e+00, -4.34531069e+00],
#        [-8.16943288e-01, -8.36788654e-01],
#        [-8.12519372e-01, -3.54924440e-01],
#        [-9.73983228e-01, -2.86689568e+00],
#        [-8.59264314e-01, -5.18064976e-01],
#        [-7.31748223e-01, -5.95767975e-01],
#        [-9.23305154e-01, -3.30316156e-01],
#        [-7.27720022e-01, -6.97377503e-01],
#        [-7.65780568e-01, -1.79687655e+00],
#        [-1.27267849e+00,  5.59804849e-02],
#        [-8.46332967e-01, -2.04724288e+00],
#        [-9.05606210e-01, -3.25510472e-01],
#        [-7.60918796e-01, -5.14416873e-01],
#        [-1.24303114e+00, -7.15328939e-03],
#        [-8.80635798e-01, -5.13814151e-01],
#        [-1.70941663e+00,  2.88095772e-01],
#        [-9.95697200e-01, -3.13458514e+00],
#        [-8.20947170e-01, -5.06736398e-01],
#        [-9.64791238e-01, -3.08849990e-01],
#        [-1.13414359e+00,  3.38383354e-02],
#        [-8.77600729e-01, -2.09130406e-01],
#        [-1.08675265e+00, -3.66135073e+00],
#        [-7.30669355e+00,  2.40967631e+00],
#        [-7.40830064e-01, -9.03007627e-01],
#        [-7.57456839e-01, -1.00194812e+00],
#        [-8.54999781e-01, -5.69653869e-01],
#        [-1.47928357e+00, -4.89679861e+00],
#        [-5.54163408e+00,  1.81496131e+00],
#        [-1.27378023e+00,  5.15876077e-02],
#        [-1.51360607e+00, -5.14408302e+00],
#        [-9.83384371e-01, -3.02750826e+00],
#        [-4.34808540e+00,  1.37064731e+00],
#        [-5.40264606e+00,  1.74285114e+00],
#        [-8.57960224e-01, -2.22700500e+00],
#        [-1.44012761e+00, -4.98058271e+00],
#        [-1.86198354e+00, -6.58473253e+00],
#        [-9.83785689e-01, -3.07018137e+00],
#        [-6.82174385e-01, -1.53140128e+00],
#        [-7.80401468e-01, -7.88531482e-01],
#        [-8.31031919e-01, -2.18227005e+00],
#        [-8.26582074e-01, -3.74616444e-01],
#        [-7.92554379e-01, -1.58775020e+00],
#        [-1.09651864e+00,  5.70487939e-02],
#        [-7.80780673e-01, -2.22153115e+00],
#        [-9.42131579e-01, -2.92888021e+00],
#        [-6.98167980e-01, -1.02555323e+00],
#        [-7.43556082e-01, -2.13091230e+00],
#        [-1.62481999e+00,  2.24513471e-01],
#        [-7.96549916e-01, -9.09645259e-01],
#        [-7.47653008e-01, -9.61156011e-01],
#        [-1.03336668e+00, -1.84756339e-01],
#        [-1.21453440e+00,  1.57145150e-02],
#        [-1.45900524e+00, -5.06569195e+00],
#        [-1.04055405e+00,  2.68477798e-02],
#        [-8.25606644e-01, -2.09038115e+00],
#        [-1.35391688e+00, -4.60536337e+00],
#        [-7.35131562e-01, -1.08555722e+00],
#        [-8.96647036e-01, -2.43854666e+00],
#        [-8.92086804e-01, -2.15598326e-02],
#        [-7.91847467e-01, -1.72425771e+00],
#        [-8.07503343e-01, -2.08477950e+00],
#        [-1.10145450e+00, -1.61785826e-01],
#        [-8.24947536e-01, -1.69728196e+00],
#        [-6.81157231e-01, -5.26002944e-01],
#        [-7.78524756e-01, -9.65912879e-01],
#        [-7.94205964e-01, -1.08199608e+00],
#        [-8.09990108e-01, -1.24264705e+00],
#        [-7.21872807e-01, -1.44353485e+00],
#        [-7.96202421e-01, -1.79469049e+00],
#        [-7.39039063e-01, -1.36342943e+00],
#        [-8.75706077e-01, -2.41560602e+00],
#        [-1.38352180e+00, -4.87180424e+00],
#        [-9.12321389e-01, -3.20613050e+00],
#        [-7.59703517e-01, -4.57263619e-01],
#        [-1.56606019e+00,  2.07810059e-01],
#        [-7.79848635e-01, -1.61827505e+00],
#        [-9.62194800e-01, -3.19098949e-01],
#        [-8.44201744e-01, -5.46467841e-01],
#        [-9.64635015e-01, -3.20089728e-01],
#        [-1.00143576e+00, -2.75436425e+00],
#        [-6.28960967e-01, -1.57696342e+00],
#        [-6.15758181e-01, -5.17861962e-01],
#        [-6.94887698e-01, -9.93973255e-01],
#        [-1.28331494e+00,  1.06959015e-01],
#        [-8.54183614e-01, -2.41705871e+00],
#        [-1.12624621e+00, -5.45097962e-02],
#        [-7.53482759e-01, -7.07093120e-01],
#        [-1.43823838e+00,  1.55509889e-01],
#        [-3.70044160e+00,  1.15637302e+00],
#        [-5.59758377e+00,  1.85066533e+00],
#        [-7.53333473e+00,  2.49206495e+00],
#        [-8.12017345e+00,  2.69454527e+00],
#        [-8.17109585e+00,  2.68972635e+00],
#        [-8.38814735e+00,  2.76504374e+00],
#        [-8.26125431e+00,  2.70103359e+00],
#        [-8.04644871e+00,  2.61473131e+00],
#        [-8.22791004e+00,  2.72458887e+00],
#        [-5.88946962e+00,  1.94332886e+00],
#        [-4.14438772e+00,  1.32257438e+00],
#        [-3.02906775e+00,  9.19518828e-01],
#        [-2.67921543e+00,  7.80018628e-01],
#        [-7.63686359e-01, -1.29461899e-01],
#        [-7.60333657e-01, -4.45305437e-01],
#        [-2.50603867e+00, -8.73141670e+00],
#        [-1.62608898e+00, -5.80950737e+00],
#        [-6.98749840e-01, -7.39288390e-01],
#        [-8.00064564e-01, -2.28229833e+00],
#        [-7.55440533e-01, -3.97683114e-01],
#        [-8.44529569e-01, -3.78251314e-01],
#        [-8.11942875e-01, -4.05284524e-01],
#        [-8.17130268e-01, -6.02902830e-01],
#        [-1.46772051e+00,  1.73268229e-01],
#        [-7.81549215e-01, -1.90212107e+00],
#        [-7.60323167e-01, -1.65575314e+00],
#        [-7.94996977e-01, -2.13486981e+00],
#        [-7.10943580e-01, -1.20543313e+00],
#        [-6.99295402e-01, -1.78811955e+00],
#        [-7.75321603e-01, -6.73364162e-01],
#        [-6.50173783e-01, -1.41501176e+00],
#        [-7.81642199e-01, -5.71244717e-01],
#        [-9.95720506e-01, -3.19332385e+00],
#        [-7.43503511e-01, -7.84522355e-01],
#        [-7.81952441e-01, -8.46831858e-01],
#        [-7.42384613e-01, -1.33894920e+00],
#        [-8.75543952e-01, -2.37901378e+00],
#        [-6.85847819e-01, -1.07751036e+00],
#        [-7.72291541e-01, -1.81918263e+00],
#        [-8.62338722e-01, -3.99125725e-01],
#        [-7.93147266e-01, -2.29514933e+00],
#        [-7.03880012e-01, -1.63652825e+00],
#        [-6.01262391e-01, -4.18157220e-01],
#        [-8.18159282e-01, -6.31942749e-01],
#        [-1.00906980e+00, -2.32504755e-01],
#        [-8.83840740e-01, -2.94492006e-01],
#        [-7.09351063e-01, -6.57406092e-01],
#        [-7.40939558e-01, -8.06680441e-01],
#        [-7.75824010e-01, -1.97295570e+00],
#        [-1.02226567e+00, -3.42950344e+00],
#        [-1.14475119e+00,  3.81238982e-02],
#        [-7.79010236e-01, -2.32975411e+00],
#        [-1.08235395e+00,  1.25500381e-01],
#        [-9.79490340e-01, -2.91499317e-01],
#        [-8.27102780e-01, -2.43263268e+00],
#        [-7.87278652e-01, -4.98364836e-01],
#        [-7.77511001e-01, -1.33273959e+00],
#        [-9.34914529e-01, -3.81113857e-01],
#        [-1.03648782e+00, -2.80943811e-01],
#        [-8.25962782e-01, -2.78664261e-01],
#        [-6.62231624e-01, -8.23395073e-01],
#        [-9.89618778e-01, -3.18551213e-01],
#        [-8.66769791e-01, -3.83529425e-01],
#        [-7.29807377e-01, -1.24441791e+00],
#        [-7.82945395e-01, -2.00843859e+00],
#        [-1.11284554e+00, -3.60197830e+00],
#        [-1.29143167e+00, -4.32624197e+00],
#        [-1.46789682e+00, -5.09615421e+00],
#        [-8.45547855e-01, -2.37822342e+00],
#        [-1.23492169e+00, -3.95775056e+00],
#        [-7.70469666e-01, -1.53433359e+00],
#        [-9.52628076e-01,  2.33743474e-01],
#        [-1.23687208e+00,  1.11699007e-01],
#        [-6.12196088e-01, -5.36260188e-01],
#        [-8.25263798e-01, -1.23849416e+00],
#        [-6.71641111e-01, -5.80468297e-01],
#        [-8.92507851e-01, -1.21736251e-01],
#        [-1.10197949e+00,  3.85209620e-02],
#        [-8.84209156e-01, -4.69778508e-01],
#        [-8.97912085e-01, -3.37146670e-01],
#        [-6.32028818e-01, -4.30971593e-01],
#        [-7.64882326e-01, -1.08434868e+00],
#        [-7.49888062e-01, -1.15816784e+00],
#        [-1.16962636e+00, -2.23586425e-01],
#        [-1.16741002e+00, -6.59120604e-02],
#        [-9.20931876e-01, -3.63869250e-01],
#        [-7.27975667e-01, -1.17465580e+00],
#        [-7.77378261e-01, -1.45047927e+00],
#        [-7.13603497e-01, -5.39070189e-01],
#        [-7.60175347e-01, -4.17727351e-01],
#        [-7.86081731e-01, -1.15059435e+00],
#        [-8.12385023e-01, -6.17951453e-01],
#        [-7.75993466e-01, -5.07199764e-01],
#        [-7.56852567e-01, -8.26254904e-01],
#        [-8.52288425e-01, -1.83539581e+00],
#        [-5.66685259e-01, -5.52269995e-01],
#        [-9.82082188e-01, -3.02440143e+00],
#        [-7.05470622e-01, -9.89865303e-01],
#        [-8.17759395e-01, -5.32374203e-01],
#        [-9.53930795e-01, -4.52352762e-01],
#        [-8.31952393e-01, -2.21278921e-01],
#        [-6.88880980e-01, -9.72537637e-01],
#        [-8.08604240e-01, -7.07254946e-01],
#        [-1.41094947e+00,  8.11151043e-02],
#        [-8.97603810e-01, -1.16231903e-01],
#        [-1.27431369e+00,  8.97953436e-02],
#        [-1.26582026e+00,  2.14151945e-02],
#        [-1.15745640e+00, -7.89586902e-02],
#        [-8.17439258e-01, -7.63747275e-01],
#        [-8.37673068e-01, -6.60069048e-01],
#        [-1.02842736e+00, -2.21606493e-01],
#        [-1.01085484e+00, -3.85562569e-01],
#        [-7.97898114e-01, -7.55641997e-01],
#        [-8.56087804e-01, -2.03075171e+00],
#        [-8.72010827e-01, -2.72096062e+00],
#        [-8.77080679e-01, -7.46120751e-01],
#        [-9.02656972e-01, -2.56072950e+00],
#        [-6.59578860e-01, -1.00534916e+00],
#        [-7.57117331e-01, -1.28243113e+00],
#        [-1.15894091e+00, -2.81223506e-02],
#        [-1.79954374e+00,  3.51688802e-01],
#        [-1.91227376e+00,  3.93876284e-01],
#        [-1.47694111e+00,  1.34798512e-01],
#        [-1.84415627e+00,  3.63210797e-01],
#        [-2.46190715e+00,  6.74327791e-01],
#        [-3.45340991e+00,  1.05854762e+00],
#        [-3.83317614e+00,  1.19882572e+00],
#        [-3.80446291e+00,  1.20895612e+00],
#        [-3.25339770e+00,  9.90147829e-01],
#        [-2.17265797e+00,  5.66858351e-01],
#        [-1.78124857e+00,  3.83365661e-01],
#        [-1.25325239e+00,  3.38539034e-02],
#        [-9.73910093e-01, -2.67011195e-01],
#        [-7.66548932e-01, -1.72300899e+00],
#        [-1.13248825e+00, -3.75987482e+00],
#        [-1.80131865e+00, -6.31619787e+00],
#        [-2.01613903e+00, -7.01147652e+00],
#        [-8.67082834e-01, -2.55792475e+00],
#        [-7.86336780e-01, -1.92586219e+00],
#        [-8.56533647e-01, -6.36445940e-01],
#        [-8.57822776e-01, -6.96706235e-01],
#        [-7.80609190e-01, -5.80490112e-01],
#        [-8.87551904e-01, -7.37700701e-01],
#        [-7.74213493e-01, -1.64198601e+00],
#        [-1.07899535e+00, -1.22819886e-01],
#        [-1.48365748e+00,  1.87944382e-01],
#        [-8.43890190e-01, -2.21136785e+00],
#        [-1.05068040e+00, -3.35812235e+00],
#        [-1.91373158e+00, -6.76972246e+00],
#        [-7.01481283e-01, -8.58228862e-01],
#        [-7.87635744e-01, -2.01913857e+00],
#        [-7.29860783e-01, -1.13224351e+00],
#        [-9.27165151e-01, -2.76087546e+00],
#        [-7.17459559e-01, -5.24512827e-01],
#        [-1.10452533e+00, -3.70012164e+00],
#        [-7.89714277e-01, -2.39495277e+00],
#        [-7.23740578e-01, -1.90232193e+00],
#        [-8.68867278e-01, -3.91897231e-01],
#        [-1.11440957e+00, -9.19939205e-02],
#        [-7.78937221e-01, -1.66265416e+00],
#        [-7.58757770e-01, -1.22507977e+00],
#        [-9.25876796e-01, -3.33276093e-01],
#        [-1.17646050e+00,  6.89289570e-02],
#        [-8.67423952e-01, -4.27460819e-01],
#        [-9.69856679e-01, -3.02471966e-01],
#        [-9.18898046e-01, -2.54442286e+00],
#        [-8.62134814e-01, -2.20851970e+00],
#        [-8.49929929e-01, -6.53099239e-01],
#        [-1.79665840e+00, -6.34464598e+00],
#        [-1.38491690e+00,  2.59236336e-01],
#        [-1.35080290e+00,  1.36441171e-01],
#        [-1.26292062e+00,  2.84080077e-02],
#        [-1.15160942e+00, -1.01881269e-02],
#        [-1.29741061e+00,  9.97055694e-02],
#        [-1.24023449e+00, -4.00193834e+00],
#        [-1.28486741e+00, -4.28557062e+00],
#        [-6.99370921e-01, -1.57869077e+00],
#        [-8.18403661e-01, -2.32786036e+00],
#        [-7.03621566e-01, -1.38919950e+00],
#        [-6.70277953e-01, -7.60571718e-01],
#        [-7.83738732e-01, -5.98563433e-01],
#        [-9.15845752e-01, -3.42778206e-01],
#        [-1.05350506e+00, -2.83703774e-01],
#        [-8.02193642e-01, -2.04473090e+00],
#        [-8.72380257e-01, -4.71061826e-01],
#        [-7.57407606e-01, -8.59704554e-01],
#        [-1.31026351e+00,  1.13403566e-01],
#        [-9.61876631e-01, -2.99421763e+00],
#        [-1.05728924e+00, -3.40886259e+00],
#        [-9.79957104e-01, -3.20658398e+00],
#        [-9.85987723e-01, -3.18985373e-01],
#        [-7.33896911e-01, -1.54415917e+00],
#        [-7.98359871e-01, -2.25675106e+00],
#        [-7.15198338e-01, -1.06888354e+00],
#        [-7.07152426e-01, -6.60468757e-01],
#        [-1.04996181e+00, -3.24909210e+00],
#        [-1.18355978e+00, -3.74427009e+00],
#        [-8.71908307e-01, -2.20800591e+00],
#        [-8.19577396e-01, -1.79929936e+00],
#        [-8.44487965e-01, -2.61382818e+00],
#        [-1.53494370e+00, -5.37442827e+00],
#        [-1.46329308e+00, -5.14882469e+00],
#        [-7.14035153e-01, -1.02932215e+00],
#        [-8.33459914e-01, -4.25191462e-01],
#        [-1.03731430e+00, -2.60924459e-01],
#        [-7.65520692e-01, -6.41096890e-01],
#        [-7.29861557e-01, -1.12232363e+00],
#        [-6.67308211e-01, -1.18857348e+00],
#        [-8.29790652e-01, -1.73595384e-01],
#        [-9.28432763e-01, -2.63390803e+00],
#        [-7.04347491e-01, -5.03882289e-01],
#        [-7.35695302e-01, -6.65769041e-01],
#        [-1.23783767e+00, -3.04790940e-02],
#        [-1.01165462e+00, -2.69718021e-01],
#        [-9.46426332e-01, -2.37930059e-01],
#        [-8.32407713e-01, -3.07037830e+00],
#        [-1.12960684e+00, -4.07046986e+00],
#        [-7.39471495e-01, -1.28609455e+00],
#        [-8.41313303e-01, -4.73723769e-01],
#        [-7.48549879e-01, -1.41665828e+00],
#        [-8.31638396e-01, -8.60412955e-01],
#        [-6.99181020e-01, -1.53418696e+00],
#        [-7.04705894e-01, -1.56426108e+00],
#        [-7.24483013e-01, -1.85853815e+00],
#        [-7.44630992e-01, -7.54715979e-01],
#        [-1.77087164e+00,  3.55304778e-01],
#        [-2.39493036e+00,  6.16210997e-01],
#        [-8.23547661e-01, -2.98054107e-02],
#        [-8.83248627e-01, -2.22032547e+00],
#        [-7.61491060e-01, -2.14110255e+00],
#        [-7.33610809e-01, -1.18178642e+00],
#        [-1.79955691e-01, -2.17107058e-01],
#        [-7.03140259e-01, -9.65157092e-01],
#        [-6.99927747e-01, -1.38544977e+00],
#        [-9.07991767e-01, -2.66646838e+00],
#        [-9.65462863e-01, -1.52868181e-01],
#        [-8.47596884e-01, -2.59552932e+00],
#        [-1.26556313e+00, -4.21687078e+00],
#        [-1.29186642e+00, -4.43709564e+00],
#        [-1.15390539e+00, -3.73777151e+00],
#        [-1.17022812e+00, -1.19533934e-01],
#        [-1.19020927e+00, -3.50846723e-02],
#        [-1.45436215e+00, -5.09397507e+00],
#        [-7.69617021e-01, -1.32904088e+00],
#        [-8.12945485e-01, -8.36713195e-01],
#        [-6.33850932e-01, -1.00272262e+00],
#        [-7.89862096e-01, -1.55958390e+00],
#        [-7.84519076e-01, -9.63367403e-01],
#        [-1.04010189e+00, -3.39138222e+00]], dtype=float32)

# %%
Skip_Gram_model_result = dict(zip(words, vectors))

# %%
Skip_Gram_model.most_similar('미세먼지/Noun', topn=5)
# Out:
# C:\Users\sora\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('#공기청정기추천/Hashtag', 0.999934196472168),
#  ('좀/Noun', 0.9998816251754761),
#  ('초등학교/Noun', 0.9998776912689209),
#  ('낫/Noun', 0.9998637437820435),
#  ('심하다고/Adjective', 0.9998319745063782)]

# %%
import pandas as pd
w2v_df = pd.DataFrame(vectors, columns = ['x1', 'x2'])
w2v_df['word'] = words
w2v_df = w2v_df[['word', 'x1', 'x2']]
w2v_df
# Out:
#                  word        x1        x2
# 0           미세먼지/Noun -0.656311 -0.773581
# 1          공기청정기/Noun -0.645916 -0.967986
# 2            /Foreign -0.852592  0.093399
# 3      #공기청정기/Hashtag -2.175254  0.744337
# 4            들/Suffix -0.727317 -0.924321
# 5       #미세먼지/Hashtag -3.136948  1.113490
# 6            마스크/Noun -0.743837 -0.222446
# 7            적/Suffix -1.979110  0.645671
# 8             하는/Verb -0.751774 -1.040249
# 9         #공해/Hashtag -4.804929  1.738785
# 10        #매연/Hashtag -5.132860  1.847081
# 11       #마스크/Hashtag -5.450405  1.966107
# 12       #SUV/Hashtag -5.553822  2.009523
# 13       #노후차/Hashtag -5.558263  2.011961
# 14      #배출가스/Hashtag -5.823596  2.092067
# 15      #자연보호/Hashtag -5.891455  2.125097
# 16      #대기오염/Hashtag -5.743029  2.062408
# 17      #환경오염/Hashtag -5.650774  2.023600
# 18      #발암물질/Hashtag -5.285560  1.900914
# 19      #유해물질/Hashtag -4.956628  1.784728
# 20      #역학조사/Hashtag -4.533465  1.628397
# 21     #집단소송제/Hashtag -3.718856  1.337315
# 22            징벌/Noun -3.348349  1.176721
# 23       손해배상/Foreign -2.749401  0.958124
# 24            중국/Noun -0.710091 -1.563542
# 25            우리/Noun -0.670533 -1.136060
# 26             집/Noun -0.801514 -2.041952
# 27             나/Noun -0.828021 -2.208535
# 28             이/Noun -0.744254 -0.665429
# 29             안/Noun -0.943959 -2.828218
# ..                ...       ...       ...
# 383           따라/Verb -0.748550 -1.416658
# 384            구/Noun -0.831638 -0.860413
# 385            발/Noun -0.699181 -1.534187
# 386           예산/Noun -0.704706 -1.564261
# 387            통/Noun -0.724483 -1.858538
# 388           는데/Verb -0.744631 -0.754716
# 389  ㅣ/KoreanParticle -1.770872  0.355305
# 390          이이이/Noun -2.394930  0.616211
# 391        열/Modifier -0.823548 -0.029805
# 392           동안/Noun -0.883249 -2.220325
# 393           오염/Noun -0.761491 -2.141103
# 394           사용/Noun -0.733611 -1.181786
# 395  #공기청정기추천/Hashtag -0.179956 -0.217107
# 396           물질/Noun -0.703140 -0.965157
# 397           성능/Noun -0.699928 -1.385450
# 398         하겠다는/Verb -0.907992 -2.666468
# 399     어떻게/Adjective -0.965463 -0.152868
# 400     있어요/Adjective -0.847597 -2.595529
# 401           되고/Verb -1.265563 -4.216871
# 402     멀쩡한/Adjective -1.291866 -4.437096
# 403         전기요금/Noun -1.153905 -3.737772
# 404           정국/Noun -1.170228 -0.119534
# 405        고/Modifier -1.190209 -0.035085
# 406         꾸꾸/Adverb -1.454362 -5.093975
# 407     망하는/Adjective -0.769617 -1.329041
# 408           검색/Noun -0.812945 -0.836713
# 409           살수/Noun -0.633851 -1.002723
# 410           방식/Noun -0.789862 -1.559584
# 411           처음/Noun -0.784519 -0.963367
# 412           투자/Noun -1.040102 -3.391382
#
# [413 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rc
import matplotlib.font_manager as fm
font_list=fm.findSystemFonts(fontpaths=None,fontext='ttf')
plt.rcParams["font.family"] = "NanumGothic"

# %%
from matplotlib.pyplot import *
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

for word, x1, x2 in zip(w2v_df['word'], w2v_df['x1'], w2v_df['x2']):
    ax.annotate(word, (x1,x2 ))
    
    
PADDING = 1.0
x_axis_min = np.amin(vectors, axis=0)[0] - PADDING
y_axis_min = np.amin(vectors, axis=0)[1] - PADDING
x_axis_max = np.amax(vectors, axis=0)[0] + PADDING
y_axis_max = np.amax(vectors, axis=0)[1] + PADDING
 
plt.xlim(x_axis_min,x_axis_max)
plt.ylim(y_axis_min,y_axis_max)
# 차트 크기.
plt.rcParams["figure.figsize"] = (10,20)

plt.show()

# %%
# 아쉬운대로 word cloud만들기
from wordcloud import WordCloud
from collections import Counter

# %%
text=""
for i in range((len(list_of_tweets))) :
    text+=(list_of_tweets[i].text)

# %%
#명사만 추출
def only_Noun(text):
    n_list = []
    for s in text.split('\n'):
        # 지정된 요소 아닌 것들만.
        n_list.extend([p[0] for p in twitter.pos(s) if (p[1] =="Noun")])
    return n_list

# %%
list_n=only_Noun(text)

# %%
list_n
# Out:
# ['진짜',
#  '나',
#  '탈',
#  '한국',
#  '한국',
#  '외국',
#  '가면',
#  '공부',
#  '애',
#  '이',
#  '인간',
#  '인간',
#  '전',
#  '한국',
#  '교육',
#  '열',
#  '제발',
#  '미세먼지',
#  '교육청',
#  '초등학교',
#  '공기청정기',
#  '중',
#  '고등학교',
#  '공기청정기',
#  '중국산',
#  '미세먼지',
#  '샤오미',
#  '공기청정기',
#  '반중',
#  '불매운동',
#  '확산',
#  '출처',
#  '국민일보',
#  '네이버',
#  '시리얼',
#  '머리',
#  '말리',
#  '바로',
#  '가야',
#  '얼굴',
#  '부워',
#  '얼굴',
#  '무거',
#  '웤',
#  '미세먼지',
#  '좀',
#  '숨쉬기',
#  '증말',
#  '공기청정기',
#  '비염',
#  '필수',
#  '생존',
#  '템',
#  '점막',
#  '손상',
#  '코피',
#  '건가',
#  '출혈',
#  '콧구멍',
#  '혈관',
#  '어캐',
#  '검열',
#  '택배',
#  '사람',
#  '이번',
#  '주',
#  '배달',
#  '물량중',
#  '가장',
#  '제품',
#  '무엇',
#  '요',
#  '제',
#  '가장',
#  '마스크',
#  '공기청정기',
#  '미세먼지',
#  '심각',
#  '분',
#  '시간',
#  '좀더',
#  '황사',
#  '외부',
#  '일',
#  '건강',
#  '유의',
#  '박',
#  '숭',
#  '미세먼지',
#  '페인트',
#  '뉴스',
#  '옥상',
#  '양봉',
#  '공기청정기',
#  '설치',
#  '하란',
#  '사람',
#  '짓',
#  '대가리',
#  '게',
#  '게',
#  '것',
#  '이',
#  '너른',
#  '천지',
#  '공기청정기',
#  '미세먼지',
#  '상식',
#  '도저히',
#  '이해',
#  '그',
#  '돈',
#  '모든',
#  '국민',
#  '마스크',
#  '배부',
#  '게',
#  '훨',
#  '낫',
#  '국민',
#  '여러분',
#  '미세먼지',
#  '방독면',
#  '쇼',
#  '공기청정기',
#  '쇼',
#  '우리',
#  '회사',
#  '더',
#  '공기청정기',
#  '건물',
#  '미세먼지',
#  '잔뜩',
#  '요즘',
#  '목도',
#  '안',
#  '눈',
#  '뭔가',
#  '나',
#  '감기',
#  '두',
#  '달',
#  '정도',
#  '안',
#  '낫',
#  '봄',
#  '좀',
#  '겨울',
#  '애기',
#  '요즘',
#  '미세먼지',
#  '인천',
#  '가장',
#  '학교',
#  '공기청정기',
#  '설치',
#  '다행',
#  '미세먼지',
#  '스모그',
#  '징벌',
#  '공기',
#  '양극화',
#  '말',
#  '마스크',
#  '공기청정기',
#  '소득공제',
#  '징벌',
#  '손바닥',
#  '해',
#  '징벌',
#  '징벌',
#  '자연',
#  '발생',
#  '미세먼지',
#  '말',
#  '이건',
#  '스모그',
#  '징벌',
#  '미세먼지',
#  '국민',
#  '누',
#  '판',
#  '과거',
#  '정부',
#  '때문',
#  '속',
#  '사람',
#  '민심',
#  '뉴스',
#  '보도',
#  '지지율',
#  '반대',
#  '좀',
#  '거리',
#  '대형',
#  '공기청정기',
#  '대책',
#  '실효',
#  '출처',
#  '네이버',
#  '뉴스',
#  '출연',
#  '쿠쿠',
#  '유위',
#  '니아',
#  '공기청정기',
#  '수요',
#  '상반기',
#  '호실',
#  '예고',
#  '미세먼지',
#  '특수',
#  '이건',
#  '진짜',
#  '오늘',
#  '내',
#  '힐링',
#  '영상',
#  '리스트',
#  '추가',
#  '혐생',
#  '중',
#  '보고',
#  '개',
#  '웃음',
#  '지음',
#  '보고',
#  '정색',
#  '전',
#  '완전',
#  '무장해제',
#  '웃음',
#  '보고',
#  '미세먼지',
#  '몸',
#  '마음',
#  '싹',
#  '정화',
#  '공기청정기',
#  '무슨',
#  '필요',
#  '이',
#  '영상',
#  '하나',
#  '새',
#  '사람',
#  '공기청정기',
#  '제습기',
#  '가습기',
#  '스타',
#  '미세먼지',
#  '제거',
#  '용',
#  '에어컨',
#  '난',
#  '방기',
#  '정도',
#  '윤택',
#  '삶',
#  '수',
#  '거',
#  '살',
#  '등신',
#  '미세먼지',
#  '어제',
#  '오늘',
#  '일도',
#  '중국',
#  '항의',
#  '미세먼지',
#  '미세먼지',
#  '퍼센트',
#  '기레기',
#  '허풍',
#  '거',
#  '공기청정기',
#  '광고',
#  '포심',
#  '조장',
#  '아주',
#  '미세먼지',
#  '못',
#  '인간',
#  '요즘',
#  '공기청정기',
#  '조사',
#  '판매',
#  '업자',
#  '미세먼지',
#  '사랑',
#  '함',
#  '공기청정기',
#  '마스크',
#  '난',
#  '극한',
#  '미세먼지',
#  '속',
#  '동스청',
#  '알',
#  '미세먼지',
#  '지난',
#  '일주일',
#  '간의',
#  '등교',
#  '로',
#  '던',
#  '스트레스',
#  '버렷',
#  '슈짐',
#  '나',
#  '공기청정기',
#  '야자',
#  '때',
#  '응원',
#  '컵',
#  '미세먼지',
#  '속',
#  '청정',
#  '공기청정기',
#  '역할',
#  '동기부여',
#  '장임',
#  '울',
#  '태형',
#  '잉',
#  '미세먼지',
#  '집',
#  '공기청정기',
#  '연탄',
#  '미세먼지',
#  '이산화탄소',
#  '미세먼지',
#  '방사',
#  '능',
#  '어차피',
#  '공기청정기',
#  '장사',
#  '노',
#  '나중',
#  '가습기',
#  '문제',
#  '일',
#  '해',
#  '태양광',
#  '공기청정기',
#  '숲',
#  '건',
#  '미세먼지',
#  '대기오염',
#  '상관',
#  '일일',
#  '아아',
#  '사립',
#  '갓',
#  '사립',
#  '공기청정기',
#  '실내',
#  '환경',
#  '미세먼지',
#  '흡입',
#  '시발',
#  '일이',
#  '진짜',
#  '세상',
#  '난리',
#  '난리',
#  '민윥기',
#  '가나',
#  '나라',
#  '민윥기',
#  '각박',
#  '한세상',
#  '윥기너',
#  '하나로',
#  '진짜',
#  '미세먼지',
#  '너',
#  '공기청정기',
#  '오조오억',
#  '느낌',
#  '윥기',
#  '진짜',
#  '주접',
#  '이아',
#  '니아',
#  '사실',
#  '생일',
#  '축하',
#  '뽀짝',
#  '공기청정기',
#  '틀',
#  '창문',
#  '꽉',
#  '이산화탄소',
#  '숨',
#  '교실',
#  '뉴스',
#  '최근',
#  '뉴스',
#  '공기조화',
#  '설비',
#  '미세먼지',
#  '대응',
#  '한계',
#  '환기',
#  '위해',
#  '외',
#  '일부',
#  '도입',
#  '내부',
#  '내기',
#  '일부',
#  '리턴',
#  '수준',
#  '유지',
#  '것',
#  '메인',
#  '애기',
#  '언니',
#  '맴',
#  '조지',
#  '흔드',
#  '살',
#  '내',
#  '수명',
#  '니',
#  '연장',
#  '마스크',
#  '공기청정기',
#  '사실',
#  '얼른',
#  '미세먼지',
#  '흡수',
#  '수명',
#  '생각',
#  '엇어',
#  '나',
#  '항뇬',
#  '독',
#  '마님',
#  '미세먼지',
#  '공기청정기',
#  '나',
#  '나',
#  '요즘',
#  '미세먼지',
#  '공기청정기',
#  '하나',
#  '사서',
#  '집',
#  '려고',
#  '정말',
#  '민윤기',
#  '보고',
#  '미세먼지',
#  '인간',
#  '공기청정기',
#  '지정',
#  '성영',
#  '세계관',
#  '미세먼지',
#  '공기청정기',
#  '능력',
#  '소유자',
#  '명',
#  '공기청정기',
#  '집안',
#  '공기',
#  '정화',
#  '의미',
#  '사람',
#  '집안',
#  '살',
#  '수',
#  '어찌',
#  '피',
#  '미세먼지',
#  '그대로',
#  '상규',
#  '머',
#  '하늘',
#  '미세먼지',
#  '데',
#  '공기청정기',
#  '놨는',
#  '거',
#  '잔뜩',
#  '컴백',
#  '준비',
#  '밥',
#  '안',
#  '연습',
#  '미세먼지',
#  '심해',
#  '탐정',
#  '걱정',
#  '아무로',
#  '탐정',
#  '위',
#  '공기청정기',
#  '구매',
#  '이제',
#  '코난',
#  '포',
#  '와로',
#  '존나',
#  '룸메',
#  '말',
#  '안통',
#  '공기청정기',
#  '오존',
#  '뭐',
#  '창문',
#  '미세먼지',
#  '시발',
#  '공기청정기',
#  '필터',
#  '도착',
#  '기념',
#  '미세먼지',
#  '수도',
#  '미세먼지',
#  '도착',
#  '필터',
#  '원망',
#  '그냥',
#  '온',
#  '필터',
#  '부천시',
#  '봄철',
#  '미세먼지',
#  '감',
#  '대책',
#  '추진',
#  '살수차',
#  '분진',
#  '흡입',
#  '차량',
#  '운영',
#  '시간',
#  '확대',
#  '경로당',
#  '등',
#  '공기청정기',
#  '운영',
#  '지역',
#  '세터',
#  '마스크',
#  '보급',
#  '봄철',
#  '미세먼지',
#  '감',
#  '대책',
#  '추진',
#  '살수차',
#  '분진',
#  '흡입',
#  '차량',
#  '운영',
#  '시간',
#  '확대',
#  '경로당',
#  '등',
#  '공기청정기',
#  '운영',
#  '지역',
#  '세터',
#  '마스크',
#  '보급',
#  '봄철',
#  '미세먼지',
#  '감',
#  '대책',
#  '추진',
#  '살수차',
#  '분진',
#  '흡입',
#  '차량',
#  '운영',
#  '시간',
#  '확대',
#  '경로당',
#  '등',
#  '공기청정기',
#  '운영',
#  '지역',
#  '세터',
#  '마스크',
#  '보급',
#  '작업실',
#  '미세먼지',
#  '조',
#  '공기청정기',
#  '네',
#  '안',
#  '감기',
#  '약',
#  '한번',
#  '더',
#  '죽',
#  '약',
#  '정말',
#  '미세먼지',
#  '제',
#  '목',
#  '진자',
#  '중국',
#  '미세먼지',
#  '어케',
#  '공기청정기',
#  '고민',
#  '이제',
#  '반장',
#  '선거',
#  '공약',
#  '미세먼지',
#  '시작',
#  '함',
#  '우리',
#  '반',
#  '미세먼지',
#  '공기청정기',
#  '제',
#  '관리',
#  '슴',
#  '미세먼지',
#  '이번',
#  '주의',
#  '기분',
#  '준',
#  '공기청정기',
#  '기범이',
#  '폴라로이드',
#  '피스',
#  '넷',
#  '미세먼지',
#  '공기청정기',
#  '공기청정기',
#  '추천',
#  '피스',
#  '넷',
#  '퓨어',
#  '진짜',
#  '가격',
#  '대비',
#  '공기청정기',
#  '고민',
#  '바로',
#  '구매',
#  '단계',
#  '제',
#  '기준',
#  '거의',
#  '무',
#  '소음',
#  '전',
#  '그냥',
#  '단계',
#  '계속',
#  '켜',
#  '욤',
#  '강',
#  '공기청정기',
#  '돈',
#  '조금',
#  '얼마',
#  '전',
#  '최악',
#  '미세먼지',
#  '생각',
#  '궁극',
#  '기후변화',
#  '영향',
#  '살',
#  '곳',
#  '게',
#  '목표',
#  '일단',
#  '그때',
#  '나',
#  '별것',
#  '혼자',
#  '계속',
#  '주황색',
#  '파란색',
#  '중이',
#  '요즘',
#  '공기청정기',
#  '미세먼지',
#  '경보',
#  '발령',
#  '전원',
#  '나',
#  '낫',
#  '정부',
#  '올해',
#  '안',
#  '모든',
#  '교실',
#  '를',
#  '설치',
#  '발표',
#  '얼마나',
#  '효과',
#  '공기청정기',
#  '교실',
#  '공기',
#  '질',
#  '측정',
#  '미세먼지',
#  '대신',
#  '농도',
#  '미세먼지',
#  '공기청정기',
#  '공기청정기',
#  '수치',
#  '왜',
#  '미세먼지',
#  '어제',
#  '어젠',
#  '더',
#  '바보',
#  '뉴스',
#  '공기청정기',
#  '을',
#  '설치',
#  '변화',
#  '미세먼지',
#  '이산화탄소',
#  '설마',
#  '거',
#  '학생',
#  '안',
#  '교실',
#  '측정',
#  '건가',
#  '사람',
#  '이산화탄소',
#  '창',
#  '정기',
#  '이산화탄소',
#  '오해',
#  '제',
#  '공기청정기',
#  '으',
#  '진작',
#  '탐라',
#  '미세먼지',
#  '제로',
#  '클린',
#  '탐라',
#  '겟',
#  '장',
#  '도담',
#  '당신',
#  '모습',
#  '라면',
#  '뭐',
#  '멋',
#  '말투',
#  '로',
#  '국방부',
#  '로부터',
#  '장병',
#  '건강',
#  '보호',
#  '위해',
#  '오늘',
#  '부터',
#  '각',
#  '부대',
#  '병영',
#  '생활관',
#  '를',
#  '보급',
#  '시작',
#  '공구',
#  '플러스',
#  '두번째',
#  '최저',
#  '공동',
#  '구매',
#  '상품',
#  '미세먼지',
#  '리무',
#  '버크',
#  '림',
#  '이드',
#  '로마',
#  '공기청정기',
#  '탁',
#  '터키',
#  '워',
#  '손',
#  '마사지',
#  '기',
#  '크레이지',
#  '립',
#  '에센스',
#  '타투',
#  '모션',
#  '인식',
#  '미세먼지',
#  '조심',
#  '우리',
#  '집',
#  '공기청정기',
#  '주',
#  '학',
#  '연아',
#  '공기청정기',
#  '주변',
#  '미세먼지',
#  '정부',
#  '언론',
#  '미세먼지',
#  '솔루션',
#  '요약',
#  '공기청정기',
#  '보급',
#  '유차',
#  '감축',
#  '전기차',
#  '보급',
#  '삼성',
#  '현대',
#  '먹거리',
#  '구마',
#  '잉',
#  '미세먼지',
#  '해도',
#  '마스크',
#  '안스',
#  '공기청정기',
#  '번',
#  '아주',
#  '몸',
#  '제대로',
#  '체감',
#  '돈',
#  '이번',
#  '미세먼지',
#  '분무기',
#  '산',
#  '우리',
#  '학교',
#  '과학',
#  '쌤',
#  '학생',
#  '걱정',
#  '공기청정기',
#  '하나',
#  '사비',
#  '사서',
#  '놨다',
#  '하루',
#  '철거',
#  '전적',
#  '학교',
#  '교실',
#  '공기청정기',
#  '창원시',
#  '진해',
#  '안청',
#  '초등학교',
#  '미세먼지',
#  '때문',
#  '아이',
#  '코',
#  '고름',
#  '이',
#  '말',
#  '여름',
#  '이',
#  '미세먼지',
#  '지옥',
#  '생각',
#  '살기',
#  '거',
#  '닥치고',
#  '실내',
#  '에어컨',
#  '공기청정기',
#  '풀',
#  '가동',
#  '것',
#  '외',
#  '대책',
#  '전기',
#  '요금',
#  '누진세',
#  '도롱',
#  '놈',
#  '미세먼지',
#  '얘기',
#  '사',
#  '미세먼지',
#  '진짜',
#  '마스크',
#  '끼',
#  '반',
#  '수업',
#  '체육',
#  '쌤',
#  '마스크',
#  '쌤',
#  '학교',
#  '너희',
#  '집',
#  '곳',
#  '너넨',
#  '집',
#  '마스크',
#  '마스크',
#  '빼',
#  '말',
#  '집',
#  '공기청정기',
#  '학교',
#  '집',
#  '공기청정기',
#  '이틀',
#  '단계',
#  '집',
#  '마스크',
#  '나',
#  '들숨',
#  '미세먼지',
#  '날숨',
#  '미세먼지',
#  '기분',
#  '미세먼지',
#  '때',
#  '대중교통',
#  '이용',
#  '대중교통',
#  '안',
#  '공기청정기',
#  '개철',
#  '소리',
#  '알',
#  '버스',
#  '먼지',
#  '고여',
#  '문',
#  '미세먼지',
#  '반복',
#  '코미디',
#  '언론',
#  '미세먼지',
#  '탓',
#  '규제',
#  '공장',
#  '규제',
#  '공포',
#  '마스크',
#  '공기청정기',
#  '필수',
#  '마스크',
#  '청정기',
#  '업계',
#  '커넥션',
#  '정부',
#  '중국',
#  '협상',
#  '미세먼지',
#  '증거',
#  '미세먼지',
#  '중국',
#  '탓',
#  '프레임',
#  '전전긍긍',
#  '전교',
#  '우리',
#  '반',
#  '반',
#  '행정',
#  '실',
#  '교무',
#  '실만',
#  '공기청정기',
#  '설치',
#  '다행',
#  '내',
#  '입학',
#  '때',
#  '해',
#  '이정',
#  '미세먼지',
#  '상상',
#  '우어',
#  '미세먼지',
#  '화분',
#  '증도',
#  '찍',
#  '집도',
#  '공기청정기',
#  '국방부',
#  '미세먼지',
#  '땜',
#  ...]

# %%
#추출된 명사 빈도 추출!
count = Counter(list_n)

# %%
wc = WordCloud(font_path="NanumGothic", background_color='white', width=800, height=600)

# %%
cloud = wc.generate_from_frequencies(dict(count))

# %%
plt.figure(figsize=(10,8))
# 축 눈금자 x
plt.axis('off')
plt.imshow(cloud)
